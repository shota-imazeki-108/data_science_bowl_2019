# %% [markdown]
# #### DSB EDA
# - refer from https://www.kaggle.com/gpreda/2019-data-science-bowl-eda

# %%
# %run ../../utils.ipynb
# Out:
# done

# %%
import numpy as np
import pandas as pd
import os
import json
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
# %matplotlib inline 
from collections import Counter

import scipy.stats

# %%
input_path = '../input/'

specs_df = pd.read_csv(os.path.join(input_path, 'specs.csv'))
train_df = pd.read_csv(os.path.join(input_path, 'train.csv'))
train_labels_df = pd.read_csv(os.path.join(input_path, 'train_labels.csv'))
test_df = pd.read_csv(os.path.join(input_path, 'test.csv'))

specs_df = reduce_mem_usage(specs_df)
train_df = reduce_mem_usage(train_df)
train_labels_df = reduce_mem_usage(train_labels_df)
test_df = reduce_mem_usage(test_df)
# Out:
# Mem. usage decreased to  0.01 Mb (0.0% reduction)
# Mem. usage decreased to 778.73 Mb (18.2% reduction)
# Mem. usage decreased to  0.49 Mb (48.2% reduction)
# Mem. usage decreased to 79.40 Mb (18.2% reduction)

# %%
def encode_title(train, test, train_labels):
    # encode title
    # make a list with all the unique 'titles' from the train and test set
    list_of_user_activities = list(set(train['title'].unique()).union(set(test['title'].unique())))
    # make a list with all the unique 'event_code' from the train and test set
    list_of_event_code = list(set(train['event_code'].unique()).union(set(test['event_code'].unique())))
    # make a list with all the unique worlds from the train and test set
    list_of_worlds = list(set(train['world'].unique()).union(set(test['world'].unique())))
    # create a dictionary numerating the titles
    activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))
    activities_labels = dict(zip(np.arange(len(list_of_user_activities)), list_of_user_activities))
    activities_world = dict(zip(list_of_worlds, np.arange(len(list_of_worlds))))
    # replace the text titles with the number titles from the dict
    train['title'] = train['title'].map(activities_map)
    test['title'] = test['title'].map(activities_map)
    train['world'] = train['world'].map(activities_world)
    test['world'] = test['world'].map(activities_world)
    train_labels['title'] = train_labels['title'].map(activities_map)
    win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
    # then, it set one element, the 'Bird Measurer (Assessment)' as 4110, 10 more than the rest
    win_code[activities_map['Bird Measurer (Assessment)']] = 4110
    # convert text into datetime
    train['timestamp'] = pd.to_datetime(train['timestamp'])
    test['timestamp'] = pd.to_datetime(test['timestamp'])
    return train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels

# %%
train_df, test_df, train_labels_df, win_code, list_of_user_activities, list_of_event_code, activities_labels = encode_title(train_df, test_df, train_labels_df)

# %% [markdown]
# ### get_data

# %%
 last_activity = 0
    
user_activities_count = {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}

# new features: time spent in each activity
event_code_count = {eve: 0 for eve in list_of_event_code}
last_session_time_sec = 0

accuracy_groups = {0:0, 1:0, 2:0, 3:0}
all_assessments = []
accumulated_accuracy_group = 0
accumulated_accuracy = 0
accumulated_correct_attempts = 0 
accumulated_uncorrect_attempts = 0
accumulated_actions = 0
counter = 0
time_first_activity = float(train_df['timestamp'].values[0])
# 3850      {"distance":4,"target_distances":[1,2,3],"corr...        0006a69f
# 4153      {"correct":true,"hats":[4,8,5],"event_count":3...        0006a69f
# 6900      {"buckets":[0,0,0],"correct":true,"buckets_pla...        0006c192
# 7279      {"correct":false,"stumps":[0,0,0],"event_count...        0006c192
# 7292      {"correct":false,"stumps":[0,0,0],"event_count...        0006c192
# 7312      {"correct":false,"stumps":[2,5,3],"event_count...        0006c192
# 7341      {"correct":false,"stumps":[3,5,2],"event_count...        0006c192
# 7414      {"correct":false,"hats":[5,4,8],"event_count":...        0006c192
# 8078      {"correct":true,"hats":[4,8,5],"event_count":3...        00129856
# 10098     {"correct":false,"stumps":[0,0,0],"event_count...        001d0ed0
# 10124     {"correct":true,"stumps":[1,2,4],"event_count"...        001d0ed0
# 10164     {"correct":true,"stumps":[1,2,4],"event_count"...        001d0ed0
# 10352     {"correct":true,"left":[{"id":"gem07","weight"...        001d0ed0
# 10379     {"scale_weights":2,"target_weight":1,"table_we...        001d0ed0
# 10384     {"scale_weights":3,"target_weight":1,"table_we...        001d0ed0
# 10390     {"scale_weights":4,"target_weight":1,"table_we...        001d0ed0
# 10428     {"scale_weights":3,"target_weight":1,"table_we...        001d0ed0
# 10467     {"correct":false,"pillars":[1],"event_count":2...        001d0ed0
# 13343     {"distance":10,"target_distances":[1,2,3],"cor...        00279ac5
# ...                                                     ...             ...
# 11330558  {"correct":true,"left":[{"id":"gem07","weight"...        ffc90c32
# 11330617  {"scale_weights":3,"target_weight":3,"table_we...        ffc90c32
# 11330626  {"scale_weights":2,"target_weight":2,"table_we...        ffc90c32
# 11330651  {"scale_weights":1,"target_weight":1,"table_we...        ffc90c32
# 11330665  {"scale_weights":4,"target_weight":4,"table_we...        ffc90c32
# 11330675  {"scale_weights":3,"target_weight":3,"table_we...        ffc90c32
# 11330685  {"scale_weights":2,"target_weight":2,"table_we...        ffc90c32
# 11330704  {"scale_weights":1,"target_weight":1,"table_we...        ffc90c32
# 11330722  {"scale_weights":5,"target_weight":5,"table_we...        ffc90c32
# 11330803  {"correct":true,"pillars":[1,2,3],"event_count...        ffc90c32
# 11333391  {"buckets":[0,0,0],"correct":true,"buckets_pla...        ffd2871d
# 11333767  {"scale_weights":6,"target_weight":3,"table_we...        ffd2871d
# 11337187  {"buckets":[0,0,0],"correct":false,"buckets_pl...        ffeb0b1b
# 11337213  {"buckets":[0,0,0],"correct":false,"buckets_pl...        ffeb0b1b
# 11337238  {"buckets":[0,0,0],"correct":true,"buckets_pla...        ffeb0b1b
# 11337675  {"correct":false,"stumps":[0,0,0],"event_count...        ffeb0b1b
# 11337779  {"buckets":[0,0,0],"correct":false,"buckets_pl...        ffeb0b1b
# 11337794  {"buckets":[0,0,0],"correct":false,"buckets_pl...        ffeb0b1b
# 11337808  {"buckets":[0,0,0],"correct":true,"buckets_pla...        ffeb0b1b
# 11338666  {"distance":7,"target_distances":[1,2,3,4],"co...        ffecb712
# 11338675  {"distance":5,"target_distances":[1,2,3,4],"co...        ffecb712
# 11338684  {"distance":4,"target_distances":[1,2,3,4],"co...        ffecb712
# 11338697  {"distance":4,"target_distances":[1,2,3],"corr...        ffecb712
# 11338705  {"distance":5,"target_distances":[1,2,3],"corr...        ffecb712
# 11338713  {"distance":2,"target_distances":[1,2,3],"corr...        ffecb712
# 11338726  {"distance":9,"target_distances":[6,7,8],"corr...        ffecb712
# 11338735  {"distance":9,"target_distances":[6,7,8],"corr...        ffecb712
# 11338744  {"distance":4,"target_distances":[6,7,8],"corr...        ffecb712
# 11338753  {"distance":5,"target_distances":[6,7,8],"corr...        ffecb712
# 11338761  {"distance":3,"target_distances":[6,7,8],"corr...        ffecb712
#
#           event_count  event_code  game_time  title        type  world
# 2228               44        4100      31011     35  Assessment      2
# 2308               76        4100     114370     33        Game      2
# 2335              103        4100     135341     33        Game      2
# 2375              143        4100     161258     33        Game      2
# 2409              177        4100     185103     33        Game      2
# 2797               30        4100      18026     35  Assessment      2
# 3725               29        4100      18484     35  Assessment      2
# 3734               38        4100      23043     35  Assessment      2
# 3773               35        4100      46494     33        Game      2
# 3809               71        4100      77194     33        Game      2
# 3842              104        4100     109896     33        Game      2
# 3850              112        4100     135531     33        Game      2
# 4153               30        4100      34209     16  Assessment      2
# 6900               20        4100      12635     17  Assessment      1
# 7279               43        4100      32388     35  Assessment      2
# 7292               56        4100      38139     35  Assessment      2
# 7312               76        4100      54974     35  Assessment      2
# 7341              105        4100      79992     35  Assessment      2
# 7414               54        4100      54682     16  Assessment      2
# 8078               38        4100      37535     16  Assessment      2
# 10098              30        4100      20730     35  Assessment      2
# 10124              56        4100      42998     35  Assessment      2
# 10164              32        4100      22110     35  Assessment      2
# 10352               9        4100      13811     21  Assessment      0
# 10379              13        4100      24322     38        Game      0
# 10384              18        4100      29539     38        Game      0
# 10390              24        4100      36656     38        Game      0
# 10428              62        4100     131713     38        Game      0
# 10467              25        4100      34514     11  Assessment      0
# 13343             100        4100     123573     33        Game      2
# ...               ...         ...        ...    ...         ...    ...
# 11330558           29        4100      21571     21  Assessment      0
# 11330617           12        4100      22735     38        Game      0
# 11330626           21        4100      32430     38        Game      0
# 11330651           46        4100      45388     38        Game      0
# 11330665           60        4100      62834     38        Game      0
# 11330675           70        4100      72535     38        Game      0
# 11330685           80        4100      82197     38        Game      0
# 11330704           99        4100      96454     38        Game      0
# 11330722          117        4100     115807     38        Game      0
# 11330803           32        4100      33986     11  Assessment      0
# 11333391           26        4100      37243     17  Assessment      1
# 11333767           32        4100      43869     38        Game      0
# 11337187           23        4100      29364     17  Assessment      1
# 11337213           49        4100      54850     17  Assessment      1
# 11337238           73        4100      82169     17  Assessment      1
# 11337675           85        4100     107388     35  Assessment      2
# 11337779           15        4100      18675     17  Assessment      1
# 11337794           30        4100      39276     17  Assessment      1
# 11337808           43        4100      52161     17  Assessment      1
# 11338666           69        4100      98515     33        Game      2
# 11338675           78        4100     115012     33        Game      2
# 11338684           87        4100     131885     33        Game      2
# 11338697          100        4100     149915     33        Game      2
# 11338705          108        4100     165552     33        Game      2
# 2196      {"description":"two...","identifier":"Dot_Two"...        0006a69f
# 2197      {"height":2,"coordinates":{"x":482,"y":502,"st...        0006a69f
# 2198      {"description":"and three!","identifier":"Dot_...        0006a69f
# 2199      {"coordinates":{"x":697,"y":660,"stage_width":...        0006a69f
# 2200      {"description":"and three!","identifier":"Dot_...        0006a69f
# 2201      {"duration":10173,"event_count":17,"game_time"...        0006a69f
# 2202      {"event_count":18,"game_time":10210,"event_cod...        0006a69f
# 2203      {"description":"Now order these mushrooms by h...        0006a69f
# 2204      {"coordinates":{"x":682,"y":625,"stage_width":...        0006a69f
# 2205      {"description":"Now order these mushrooms by h...        0006a69f
# 2206      {"coordinates":{"x":744,"y":379,"stage_width":...        0006a69f
# 2207      {"coordinates":{"x":311,"y":509,"stage_width":...        0006a69f
# 2208      {"height":4,"stumps":[0,0,0],"coordinates":{"x...        0006a69f
# 2209      {"height":4,"destination":"right","stumps":[0,...        0006a69f
# 2210      {"height":2,"stumps":[0,0,4],"coordinates":{"x...        0006a69f
# 2211      {"height":2,"destination":"middle","stumps":[0...        0006a69f
# 2212      {"height":1,"stumps":[0,2,4],"coordinates":{"x...        0006a69f
# 2213      {"height":1,"destination":"left","stumps":[1,2...        0006a69f
# 2214      {"description":"Okay, when you want to check y...        0006a69f
# ...                                                     ...             ...
# 11337796  {"coordinates":{"x":755,"y":378,"stage_width":...        ffeb0b1b
# 11337797  {"description":"Try moving the smallest bucket...        ffeb0b1b
# 11337798  {"bucket":1,"buckets":[0,0,0],"coordinates":{"...        ffeb0b1b
# 11337799  {"bucket":1,"coordinates":{"x":652,"y":631,"st...        ffeb0b1b
# 11337800  {"bucket":2,"buckets":[0,1,0],"coordinates":{"...        ffeb0b1b
# 11337801  {"bucket":2,"source":"middle","coordinates":{"...        ffeb0b1b
# 11337802  {"bucket":1,"buckets":[2,0,0],"coordinates":{"...        ffeb0b1b
# 11337803  {"bucket":1,"destination":"middle","coordinate...        ffeb0b1b
# 11337804  {"bucket":2,"buckets":[0,0,0],"coordinates":{"...        ffeb0b1b
# 11337805  {"bucket":2,"destination":"right","coordinates...        ffeb0b1b
# 11337806  {"description":"Okay, when you want to check y...        ffeb0b1b
# 11337807  {"misses":2,"prompt":"N/A","mode":"placing","r...        ffeb0b1b
# 11337808  {"buckets":[0,0,0],"correct":true,"buckets_pla...        ffeb0b1b
# 11337809  {"description":"Okay, when you want to check y...        ffeb0b1b
# 11337810  {"description":"That's it!","identifier":"Dot_...        ffeb0b1b
# 11337811  {"description":"That's it!","identifier":"Dot_...        ffeb0b1b
# 11337812  {"description":"Look! Each bucket is exactly t...        ffeb0b1b
# 11337813  {"description":"Look! Each bucket is exactly t...        ffeb0b1b
# 11337814  {"description":"Tap the bucket that holds the ...        ffeb0b1b
# 11337815  {"buckets":[],"target_bucket":1,"mode":"select...        ffeb0b1b
# 11337816  {"bucket":3,"buckets_placed":[3,1,2],"target_b...        ffeb0b1b
# 11337817  {"description":"Tap the bucket that holds the ...        ffeb0b1b
# 11337819           55        3110      63612     17  Assessment      1
# 11337820           56        4070      65281     17  Assessment      1
# 11337821           58        2030      67094     17  Assessment      1
# 11337822           57        4025      67094     17  Assessment      1
# 11337823           59        3021      67094     17  Assessment      1
# 11337824           60        3121      67847     17  Assessment      1
# 11337825           61        2010      71511     17  Assessment      1
#
# [925345 rows x 11 columns]

# %%
session = train_df[train_df.game_session=='901acc108f55a5a1']
i =1

session_type = session['type'].iloc[0]
session_title = session['title'].iloc[0]

all_attempts = session.query(f'event_code == {win_code[session_title]}')
# then, check the numbers of wins and the number of losses
true_attempts = all_attempts['event_data'].str.contains('true').sum()
false_attempts = all_attempts['event_data'].str.contains('false').sum()

all_attempts.head()
# Out:
#       event_id      game_session                        timestamp  \
# 2228  25fa8af4  901acc108f55a5a1 2019-08-06 05:22:32.357000+00:00
#
#                                              event_data installation_id  \
# 2228  {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
#
#       event_count  event_code  game_time  title        type  world
# 2228           44        4100      31011     35  Assessment      2

# %%
features = user_activities_count.copy()
features.update(event_code_count.copy())
features['installation_id'] = session['installation_id'].iloc[-1]
features['session_title'] = session['title'].iloc[0]

features['accumulated_correct_attempts'] = accumulated_correct_attempts
features['accumulated_uncorrect_attempts'] = accumulated_uncorrect_attempts
accumulated_correct_attempts += true_attempts 
accumulated_uncorrect_attempts += false_attempts

# %%
if durations == []:
    features['duration_mean'] = 0
else:
    features['duration_mean'] = np.mean(durations)
durations.append((session.iloc[-1, 2] - session.iloc[0, 2] ).seconds)

# %%
features['accumulated_accuracy'] = accumulated_accuracy/counter if counter > 0 else 0
accuracy = true_attempts/(true_attempts+false_attempts) if (true_attempts+false_attempts) != 0 else 0
accumulated_accuracy += accuracy
if accuracy == 0:
    features['accuracy_group'] = 0
elif accuracy == 1:
    features['accuracy_group'] = 3
elif accuracy == 0.5:
    features['accuracy_group'] = 2
else:
    features['accuracy_group'] = 1
features.update(accuracy_groups)
accuracy_groups[features['accuracy_group']] += 1

# %%
features['accumulated_accuracy_group'] = accumulated_accuracy_group/counter if counter > 0 else 0
accumulated_accuracy_group += features['accuracy_group']
features['accumulated_actions'] = accumulated_actions

# %%
test_set = False
if test_set:
    all_assessments.append(features)
elif true_attempts+false_attempts > 0:
    all_assessments.append(features)
counter += 1

# %%
n_of_event_codes = Counter(session['event_code'])
for key in n_of_event_codes.keys():
    event_code_count[key] += n_of_event_codes[key]

# %%
accumulated_actions += len(session)
if last_activity != session_type:
    user_activities_count[session_type] += 1
    last_activitiy = session_type

# %%
all_assessments
# Out:
# [{'Clip': 0,
#   'Activity': 0,
#   'Assessment': 0,
#   'Game': 0,
#   2050: 0,
#   4100: 0,
#   2060: 0,
#   4110: 0,
#   2070: 0,
#   2075: 0,
#   2080: 0,
#   2081: 0,
#   2083: 0,
#   3110: 0,
#   3120: 0,
#   3121: 0,
#   4220: 0,
#   4230: 0,
#   5000: 0,
#   4235: 0,
#   5010: 0,
#   4010: 0,
#   4020: 0,
#   4021: 0,
#   4022: 0,
# 8         {"coordinates":{"x":279,"y":629,"stage_width":...        0001e90f
# 9         {"coordinates":{"x":839,"y":654,"stage_width":...        0001e90f
# 10        {"coordinates":{"x":807,"y":619,"stage_width":...        0001e90f
# 11        {"coordinates":{"x":810,"y":611,"stage_width":...        0001e90f
# 12        {"coordinates":{"x":827,"y":584,"stage_width":...        0001e90f
# 13        {"coordinates":{"x":823,"y":615,"stage_width":...        0001e90f
# 14        {"coordinates":{"x":832,"y":614,"stage_width":...        0001e90f
# 15        {"coordinates":{"x":875,"y":631,"stage_width":...        0001e90f
# 16        {"coordinates":{"x":871,"y":637,"stage_width":...        0001e90f
# 17        {"coordinates":{"x":890,"y":645,"stage_width":...        0001e90f
# 18        {"description":"Drag the shovel to the molds t...        0001e90f
# 19        {"coordinates":{"x":866,"y":650,"stage_width":...        0001e90f
# 20        {"coordinates":{"x":876,"y":670,"stage_width":...        0001e90f
# 21        {"coordinates":{"x":564,"y":576,"stage_width":...        0001e90f
# 22        {"coordinates":{"x":573,"y":570,"stage_width":...        0001e90f
# 23        {"description":"Drag the shovel to the molds t...        0001e90f
# 24        {"coordinates":{"x":570,"y":542,"stage_width":...        0001e90f
# 25        {"coordinates":{"x":594,"y":532,"stage_width":...        0001e90f
# 26        {"coordinates":{"x":438,"y":594,"stage_width":...        0001e90f
# 27        {"coordinates":{"x":271,"y":645,"stage_width":...        0001e90f
# 28        {"coordinates":{"x":256,"y":637,"stage_width":...        0001e90f
# 29        {"coordinates":{"x":279,"y":614,"stage_width":...        0001e90f
# ...                                                     ...             ...
# 11341012  {"coordinates":{"x":142,"y":34,"stage_width":1...        fffc0583
# 11341013  {"coordinates":{"x":40,"y":104,"stage_width":1...        fffc0583
# 11341014  {"coordinates":{"x":52,"y":116,"stage_width":1...        fffc0583
# 11341015  {"coordinates":{"x":77,"y":63,"stage_width":10...        fffc0583
# 11341016  {"coordinates":{"x":97,"y":69,"stage_width":10...        fffc0583
# 11341017  {"coordinates":{"x":99,"y":73,"stage_width":10...        fffc0583
# 11341018  {"coordinates":{"x":74,"y":13,"stage_width":10...        fffc0583
# 11341019  {"coordinates":{"x":105,"y":41,"stage_width":1...        fffc0583
# 11341020  {"coordinates":{"x":862,"y":319,"stage_width":...        fffc0583
# 11341021  {"coordinates":{"x":846,"y":325,"stage_width":...        fffc0583
# 11341022  {"coordinates":{"x":1,"y":136,"stage_width":10...        fffc0583
# 11341023  {"coordinates":{"x":15,"y":130,"stage_width":1...        fffc0583
# 11341024  {"coordinates":{"x":57,"y":104,"stage_width":1...        fffc0583
# 11341025  {"coordinates":{"x":67,"y":81,"stage_width":10...        fffc0583
# 11341026  {"coordinates":{"x":84,"y":333,"stage_width":1...        fffc0583
# 11341027  {"coordinates":{"x":60,"y":355,"stage_width":1...        fffc0583
# 11341028  {"coordinates":{"x":74,"y":359,"stage_width":1...        fffc0583
# 11341029  {"description":"Tap another dinosaur.","identi...        fffc0583
# 11341030  {"coordinates":{"x":82,"y":113,"stage_width":1...        fffc0583
# 11341031  {"coordinates":{"x":58,"y":89,"stage_width":10...        fffc0583
# 11341032  {"description":"Tap another dinosaur.","identi...        fffc0583
# 11341033  {"coordinates":{"x":88,"y":61,"stage_width":10...        fffc0583
# 11341034  {"coordinates":{"x":101,"y":66,"stage_width":1...        fffc0583
# 11341035  {"target_water_level":0,"water_level":0,"round...        fffc0583
# 11341036  {"description":"Tap another dinosaur.","identi...        fffc0583
# 11341037  {"description":"Tap another dinosaur.","identi...        fffc0583
# 11341038             {"event_code": 2000, "event_count": 1}        fffc0583
# 11341039             {"event_code": 2000, "event_count": 1}        fffc0583
# 11341040             {"event_code": 2000, "event_count": 1}        fffc0583
# 11341041             {"event_code": 2000, "event_count": 1}        fffc0583
#
#           event_count  event_code  game_time                          title  \
# 0                   1        2000          0        Welcome to Lost Lagoon!
# 1                   1        2000          0           Magma Peak - Level 1
# 2                   1        2000          0  Sandcastle Builder (Activity)
# 3                   2        3010         53  Sandcastle Builder (Activity)
# 4                   3        3110       6972  Sandcastle Builder (Activity)
# 5                   4        4070       9991  Sandcastle Builder (Activity)
# 6                   5        4070      10622  Sandcastle Builder (Activity)
# 7                   6        4070      11255  Sandcastle Builder (Activity)
# 8                   7        4070      11689  Sandcastle Builder (Activity)
# 9                   8        4070      12272  Sandcastle Builder (Activity)
# 10                  9        4070      12672  Sandcastle Builder (Activity)
# 11                 10        4070      13389  Sandcastle Builder (Activity)
# 12                 11        4070      13639  Sandcastle Builder (Activity)
# 13                 12        4070      13872  Sandcastle Builder (Activity)
# 14                 13        4070      14122  Sandcastle Builder (Activity)
# 15                 14        4070      14356  Sandcastle Builder (Activity)
# 16                 15        4070      14622  Sandcastle Builder (Activity)
# 17                 16        4070      14889  Sandcastle Builder (Activity)
# 18                 17        3010      14956  Sandcastle Builder (Activity)
# 19                 18        4070      15306  Sandcastle Builder (Activity)
# 20                 19        4070      15539  Sandcastle Builder (Activity)
# 21                 20        4070      16089  Sandcastle Builder (Activity)
# 22                 21        4070      16672  Sandcastle Builder (Activity)
# 23                 22        3110      17056  Sandcastle Builder (Activity)
# 24                 23        4070      17289  Sandcastle Builder (Activity)
# 25                 24        4070      17489  Sandcastle Builder (Activity)
# 26                 25        4070      17839  Sandcastle Builder (Activity)
# 27                 26        4070      18093  Sandcastle Builder (Activity)
# 28                 27        4070      18273  Sandcastle Builder (Activity)
# 29                 28        4070      18573  Sandcastle Builder (Activity)
# ...               ...         ...        ...                            ...
# 11341012           41        4070      31010                      Dino Dive
# 11341013           42        4070      32393                      Dino Dive
# 11341014           43        4070      33311                      Dino Dive
# 11341015           44        4070      33610                      Dino Dive
# 11341016           45        4070      33910                      Dino Dive
# 11341017           46        4070      34277                      Dino Dive
# 11341018           47        4070      34710                      Dino Dive
# 11341019           48        4070      34960                      Dino Dive
# 11341020           49        4070      35660                      Dino Dive
# 11341021           50        4070      36211                      Dino Dive
# 11341022           51        4070      37211                      Dino Dive
# 11341023           52        4070      37510                      Dino Dive
# 11341024           53        4070      37777                      Dino Dive
# 11341025           54        4070      38060                      Dino Dive
# 11341026           55        4070      38510                      Dino Dive
# 11341027           56        4070      38910                      Dino Dive
# 11341028           57        4070      39577                      Dino Dive
# 11341029           58        3010      39860                      Dino Dive
# 11341030           59        4070      40677                      Dino Dive
# 11341031           60        4070      41077                      Dino Dive
# 11341032           61        3110      41294                      Dino Dive
# 11341033           62        4070      41711                      Dino Dive
# 11341034           63        4070      42411                      Dino Dive
# 11341035           64        4090     117165                      Dino Dive
# 11341036           65        3010     117165                      Dino Dive
# 11341037           66        3110     118615                      Dino Dive
# 11341038            1        2000          0        Crystal Caves - Level 2
# 11341039            1        2000          0        Crystal Caves - Level 3
# 11341040            1        2000          0        Crystal Caves - Level 3
# 11341041            1        2000          0        Tree Top City - Level 2
#
#               type         world
# 0             Clip          NONE
# 1             Clip     MAGMAPEAK
# 2         Activity     MAGMAPEAK
# 3         Activity     MAGMAPEAK
# 4         Activity     MAGMAPEAK
# 5         Activity     MAGMAPEAK
# 6         Activity     MAGMAPEAK
# 7         Activity     MAGMAPEAK
# 8         Activity     MAGMAPEAK
# 9         Activity     MAGMAPEAK
# 10        Activity     MAGMAPEAK
# 11        Activity     MAGMAPEAK
# 12        Activity     MAGMAPEAK
# 13        Activity     MAGMAPEAK
# 14        Activity     MAGMAPEAK
# 15        Activity     MAGMAPEAK
# 16        Activity     MAGMAPEAK
# 17        Activity     MAGMAPEAK
# 18        Activity     MAGMAPEAK
# 19        Activity     MAGMAPEAK
# 20        Activity     MAGMAPEAK
# 21        Activity     MAGMAPEAK
# 22        Activity     MAGMAPEAK
# 23        Activity     MAGMAPEAK
# 24        Activity     MAGMAPEAK
# 25        Activity     MAGMAPEAK
# 26        Activity     MAGMAPEAK
# 27        Activity     MAGMAPEAK
# 28        Activity     MAGMAPEAK
# 29        Activity     MAGMAPEAK
# ...            ...           ...
# 11341012      Game     MAGMAPEAK
# 11341013      Game     MAGMAPEAK
# 11341014      Game     MAGMAPEAK
# 11341015      Game     MAGMAPEAK
# 11341016      Game     MAGMAPEAK
# 11341017      Game     MAGMAPEAK
# 11341018      Game     MAGMAPEAK
# 11341019      Game     MAGMAPEAK
# 11341020      Game     MAGMAPEAK
# 11341021      Game     MAGMAPEAK
# 11341022      Game     MAGMAPEAK
# 11341023      Game     MAGMAPEAK
# 11341024      Game     MAGMAPEAK
# 11341025      Game     MAGMAPEAK
# 11341026      Game     MAGMAPEAK
# 11341027      Game     MAGMAPEAK
# 11341028      Game     MAGMAPEAK
# 11341029      Game     MAGMAPEAK
# 11341030      Game     MAGMAPEAK
# 11341031      Game     MAGMAPEAK
# 11341032      Game     MAGMAPEAK
# 11341033      Game     MAGMAPEAK
# 11341034      Game     MAGMAPEAK
# 11341035      Game     MAGMAPEAK
# 11341036      Game     MAGMAPEAK
# 11341037      Game     MAGMAPEAK
# 11341038      Clip  CRYSTALCAVES
# 11341039      Clip  CRYSTALCAVES
# 11341040      Clip  CRYSTALCAVES
# 11341041      Clip   TREETOPCITY
#
# [11341042 rows x 11 columns]
