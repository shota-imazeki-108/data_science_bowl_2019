# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import XGBClassifier, XGBRegressor
from xgboost import plot_importance
from catboost import CatBoostRegressor
from bayes_opt import BayesianOptimization
from matplotlib import pyplot
import seaborn as sns
import shap

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
from time import time
from tqdm import tqdm_notebook as tqdm
from collections import Counter
from scipy import stats
import lightgbm as lgb
from sklearn.metrics import cohen_kappa_score, mean_squared_error
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, GroupKFold, GridSearchCV, train_test_split, TimeSeriesSplit, RepeatedStratifiedKFold
import gc
import json
pd.set_option('display.max_columns', 1000)

# %%
import altair as alt
from bayes_opt import BayesianOptimization
import catboost as cat
from catboost import CatBoostRegressor
from category_encoders.ordinal import OrdinalEncoder
from collections import Counter
from collections import defaultdict
import datetime
import eli5
from functools import partial
import gc
from IPython.display import HTML
from itertools import product
from joblib import Parallel, delayed
import json
import lightgbm as lgb
import matplotlib.pyplot as plt
import networkx as nx
from numba import jit
import numpy as np
import os
import pandas as pd
from random import choice
import re
import seaborn as sns
from scipy import stats
import shap
from sklearn.metrics import cohen_kappa_score, mean_squared_error
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.svm import NuSVR, SVR
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, GroupKFold, GridSearchCV, train_test_split, TimeSeriesSplit, RepeatedStratifiedKFold
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import linear_model
import tensorflow as tf
from time import time
from tqdm import tqdm_notebook as tqdm
from typing import List, Any
import warnings
import xgboost as xgb
from xgboost import plot_importance
from xgboost import XGBClassifier, XGBRegressor
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Objective
#
# * In the last notebook we create our baseline model including a feature selection part.
# * Cohen cappa score of 0.456 (lb) with a local cv score of 0.529
# * In this notebook we are going to add more features and remove others that i think they overfitt the train set and then check if our local cv score improve.
# * Next, we will check if this improvement aligns with the lb.

# %% [markdown]
# # Notes
# * Check the distribution of the target variable of the out of folds score and the prediction distribution. A good model should more or less have the same distribution.

# %%
def eval_qwk_lgb_regr(y_true, y_pred):
    """
    Fast cappa eval function for lgb.
    """
    dist = Counter(reduce_train['accuracy_group'])
    for k in dist:
        dist[k] /= len(reduce_train)
    reduce_train['accuracy_group'].hist()
    
    acum = 0
    bound = {}
    for i in range(3):
        acum += dist[i]
        bound[i] = np.percentile(y_pred, acum * 100)

    def classify(x):
        if x <= bound[0]:
            return 0
        elif x <= bound[1]:
            return 1
        elif x <= bound[2]:
            return 2
        else:
            return 3

    y_pred = np.array(list(map(classify, y_pred))).reshape(y_true.shape)

    return 'cappa', cohen_kappa_score(y_true, y_pred, weights='quadratic'), True

# %%
def cohenkappa(ypred, y):
    y = y.get_label().astype("int")
    ypred = ypred.reshape((4, -1)).argmax(axis = 0)
    loss = cohenkappascore(y, y_pred, weights = 'quadratic')
    return "cappa", loss, True

# %%
def read_data():
    print('Reading train.csv file....')
    train = pd.read_csv('../input/train.csv')
    print('Training.csv file have {} rows and {} columns'.format(train.shape[0], train.shape[1]))

    print('Reading test.csv file....')
    test = pd.read_csv('../input/test.csv')
    print('Test.csv file have {} rows and {} columns'.format(test.shape[0], test.shape[1]))

    print('Reading train_labels.csv file....')
    train_labels = pd.read_csv('../input/train_labels.csv')
    print('Train_labels.csv file have {} rows and {} columns'.format(train_labels.shape[0], train_labels.shape[1]))

    print('Reading specs.csv file....')
    specs = pd.read_csv('../input/specs.csv')
    print('Specs.csv file have {} rows and {} columns'.format(specs.shape[0], specs.shape[1]))

    print('Reading sample_submission.csv file....')
    sample_submission = pd.read_csv('../input/sample_submission.csv')
    print('Sample_submission.csv file have {} rows and {} columns'.format(sample_submission.shape[0], sample_submission.shape[1]))
    return train, test, train_labels, specs, sample_submission

# %%
def encode_title(train, test, train_labels):
    # encode title
    train['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), train['title'], train['event_code']))
    test['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), test['title'], test['event_code']))
    all_title_event_code = list(set(train["title_event_code"].unique()).union(test["title_event_code"].unique()))
    # make a list with all the unique 'titles' from the train and test set
    list_of_user_activities = list(set(train['title'].unique()).union(set(test['title'].unique())))
    # make a list with all the unique 'event_code' from the train and test set
    list_of_event_code = list(set(train['event_code'].unique()).union(set(test['event_code'].unique())))
    list_of_event_id = list(set(train['event_id'].unique()).union(set(test['event_id'].unique())))
    # make a list with all the unique worlds from the train and test set
    list_of_worlds = list(set(train['world'].unique()).union(set(test['world'].unique())))
    # create a dictionary numerating the titles
    activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))
    activities_labels = dict(zip(np.arange(len(list_of_user_activities)), list_of_user_activities))
    activities_world = dict(zip(list_of_worlds, np.arange(len(list_of_worlds))))
    assess_titles = list(set(train[train['type'] == 'Assessment']['title'].value_counts().index).union(set(test[test['type'] == 'Assessment']['title'].value_counts().index)))
    # replace the text titles with the number titles from the dict
    train['title'] = train['title'].map(activities_map)
    test['title'] = test['title'].map(activities_map)
    train['world'] = train['world'].map(activities_world)
    test['world'] = test['world'].map(activities_world)
    train_labels['title'] = train_labels['title'].map(activities_map)
    win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
    # then, it set one element, the 'Bird Measurer (Assessment)' as 4110, 10 more than the rest
    win_code[activities_map['Bird Measurer (Assessment)']] = 4110
    # convert text into datetime
    train['timestamp'] = pd.to_datetime(train['timestamp'])
    test['timestamp'] = pd.to_datetime(test['timestamp'])
    
    
    return train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code

# %%
# this is the function that convert the raw data into processed features
def get_data(user_sample, test_set=False):
    '''
    The user_sample is a DataFrame from train or test where the only one 
    installation_id is filtered
    And the test_set parameter is related with the labels processing, that is only requered
    if test_set=False
    '''
    # Constants and parameters declaration
    last_activity = 0
    
    user_activities_count = {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
    
    # new features: time spent in each activity
    last_session_time_sec = 0
    accuracy_groups = {0:0, 1:0, 2:0, 3:0}
    all_assessments = []
    accumulated_accuracy_group = 0
    accumulated_accuracy = 0
    accumulated_correct_attempts = 0 
    accumulated_uncorrect_attempts = 0
    accumulated_actions = 0
    counter = 0
    time_first_activity = float(user_sample['timestamp'].values[0])
    durations = []
    last_accuracy_title = {'acc_' + title: -1 for title in assess_titles}
    event_code_count: Dict[str, int] = {ev: 0 for ev in list_of_event_code}
    event_id_count: Dict[str, int] = {eve: 0 for eve in list_of_event_id}
    title_count: Dict[str, int] = {eve: 0 for eve in activities_labels.values()} 
    title_event_code_count: Dict[str, int] = {t_eve: 0 for t_eve in all_title_event_code}
        
    # last features
    sessions_count = 0
    
    # itarates through each session of one instalation_id
    for i, session in user_sample.groupby('game_session', sort=False):
        # i = game_session_id
        # session is a DataFrame that contain only one game_session
        
        # get some sessions information
        session_type = session['type'].iloc[0]
        session_title = session['title'].iloc[0]
        session_title_text = activities_labels[session_title]
                    
            
        # for each assessment, and only this kind off session, the features below are processed
        # and a register are generated
        if (session_type == 'Assessment') & (test_set or len(session)>1):
            # search for event_code 4100, that represents the assessments trial
            all_attempts = session.query(f'event_code == {win_code[session_title]}')
            # then, check the numbers of wins and the number of losses
            true_attempts = all_attempts['event_data'].str.contains('true').sum()
            false_attempts = all_attempts['event_data'].str.contains('false').sum()
            # copy a dict to use as feature template, it's initialized with some itens: 
            # {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
            features = user_activities_count.copy()
            features.update(last_accuracy_title.copy())
            features.update(event_code_count.copy())
            features.update(event_id_count.copy())
            features.update(title_count.copy())
            features.update(title_event_code_count.copy())
            features.update(last_accuracy_title.copy())
            features['installation_session_count'] = sessions_count
            
            variety_features = [('var_event_code', event_code_count),
                              ('var_event_id', event_id_count),
                               ('var_title', title_count),
                               ('var_title_event_code', title_event_code_count)]
            
            for name, dict_counts in variety_features:
                arr = np.array(list(dict_counts.values()))
                features[name] = np.count_nonzero(arr)
                 
            # get installation_id for aggregated features
            features['installation_id'] = session['installation_id'].iloc[-1]
            # add title as feature, remembering that title represents the name of the game
            features['session_title'] = session['title'].iloc[0]
            # the 4 lines below add the feature of the history of the trials of this player
            # this is based on the all time attempts so far, at the moment of this assessment
            features['accumulated_correct_attempts'] = accumulated_correct_attempts
            features['accumulated_uncorrect_attempts'] = accumulated_uncorrect_attempts
            accumulated_correct_attempts += true_attempts 
            accumulated_uncorrect_attempts += false_attempts
            # the time spent in the app so far
            if durations == []:
                features['duration_mean'] = 0
                features['duration_std'] = 0
            else:
                features['duration_mean'] = np.mean(durations)
                features['duration_std'] = np.std(durations)
            durations.append((session.iloc[-1, 2] - session.iloc[0, 2] ).seconds)
            # the accurace is the all time wins divided by the all time attempts
            features['accumulated_accuracy'] = accumulated_accuracy/counter if counter > 0 else 0
            accuracy = true_attempts/(true_attempts+false_attempts) if (true_attempts+false_attempts) != 0 else 0
            accumulated_accuracy += accuracy
            last_accuracy_title['acc_' + session_title_text] = accuracy
            # a feature of the current accuracy categorized
            # it is a counter of how many times this player was in each accuracy group
            if accuracy == 0:
                features['accuracy_group'] = 0
            elif accuracy == 1:
                features['accuracy_group'] = 3
            elif accuracy == 0.5:
                features['accuracy_group'] = 2
            else:
                features['accuracy_group'] = 1
            features.update(accuracy_groups)
            accuracy_groups[features['accuracy_group']] += 1
            # mean of the all accuracy groups of this player
            features['accumulated_accuracy_group'] = accumulated_accuracy_group/counter if counter > 0 else 0
            accumulated_accuracy_group += features['accuracy_group']
            # how many actions the player has done so far, it is initialized as 0 and updated some lines below
            features['accumulated_actions'] = accumulated_actions
            
            # there are some conditions to allow this features to be inserted in the datasets
            # if it's a test set, all sessions belong to the final dataset
            # it it's a train, needs to be passed throught this clausule: session.query(f'event_code == {win_code[session_title]}')
            # that means, must exist an event_code 4100 or 4110
            if test_set:
                all_assessments.append(features)
            elif true_attempts+false_attempts > 0:
                all_assessments.append(features)
                
            counter += 1
        
        sessions_count += 1
        # this piece counts how many actions was made in each event_code so far
        def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = k
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            
        event_code_count = update_counters(event_code_count, "event_code")
        event_id_count = update_counters(event_id_count, "event_id")
        title_count = update_counters(title_count, 'title')
        title_event_code_count = update_counters(title_event_code_count, 'title_event_code')

        # counts how many actions the player has done so far, used in the feature of the same name
        accumulated_actions += len(session)
        if last_activity != session_type:
            user_activities_count[session_type] += 1
            last_activitiy = session_type 
                        
    # if it't the test_set, only the last assessment must be predicted, the previous are scraped
    if test_set:
        return all_assessments[-1]
    # in the train_set, all assessments goes to the dataset
    return all_assessments

# %%
def get_train_and_test(train, test):
    compiled_train = []
    compiled_test = []
    for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort = False)), total = 17000):
        compiled_train += get_data(user_sample)
    for ins_id, user_sample in tqdm(test.groupby('installation_id', sort = False), total = 1000):
        test_data = get_data(user_sample, test_set = True)
        compiled_test.append(test_data)
    reduce_train = pd.DataFrame(compiled_train)
    reduce_test = pd.DataFrame(compiled_test)
    categoricals = ['session_title']
    return reduce_train, reduce_test, categoricals

# %%
class Base_Model(object):

    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True, ps={}, target='accuracy_group'):
        self.train_df = train_df
        self.test_df = test_df
        self.features = features
        self.n_splits = n_splits
        self.categoricals = categoricals
        self.target = target
        self.cv = self.get_cv()
        self.verbose = verbose
        self.params = self.set_params(ps)
        self.y_pred, self.score, self.model = self.fit()

    def train_model(self, train_set, val_set):
        raise NotImplementedError

    def get_cv(self):
        cv = StratifiedKFold(n_splits=self.n_splits,
                             shuffle=True, random_state=42)
        return cv.split(self.train_df, self.train_df[self.target])

    def convert_dataset(self, x_train, y_train, x_val, y_val):
        raise NotImplementedError

    def convert_x(self, x):
        return x

    def fit(self):
        oof_pred = np.zeros((len(self.train_df), ))
        y_pred = np.zeros((len(self.test_df), ))
        for fold, (train_idx, val_idx) in enumerate(self.cv):
            x_train, x_val = self.train_df[self.features].iloc[train_idx], self.train_df[self.features].iloc[val_idx]
            y_train, y_val = self.train_df[self.target][train_idx], self.train_df[self.target][val_idx]
            train_set, val_set = self.convert_dataset(
                x_train, y_train, x_val, y_val)
            conv_x_val = self.convert_x(x_val)

            model = self.train_model(train_set, val_set)
            oof_pred[val_idx] = model.predict(
                conv_x_val).reshape(oof_pred[val_idx].shape)

            x_test = self.convert_x(self.test_df[self.features])
            y_pred += model.predict(x_test).reshape(y_pred.shape) / \
                self.n_splits
            print('Partial score of fold {} is: {}'.format(
                fold, eval_qwk_lgb_regr(y_val, oof_pred[val_idx])[1]))
        _, loss_score, _ = eval_qwk_lgb_regr(
            self.train_df[self.target], oof_pred)
        if self.verbose:
            print('Our oof cohen kappa score is: ', loss_score)
        return y_pred, loss_score, model

    def get_params(self):
        return None

    def set_params(self, ps={}):
        return self.get_params()

# %%
class Lgb_regr_Model(Base_Model):

    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return lgb.train(self.params, train_set, valid_sets=[train_set, val_set], verbose_eval=verbosity)

    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = lgb.Dataset(
            x_train, y_train, categorical_feature=self.categoricals)
        val_set = lgb.Dataset(
            x_val, y_val, categorical_feature=self.categoricals)
        return train_set, val_set

    def get_params(self):
        params = {'n_estimators': 5000,
                  'boosting_type': 'gbdt',
                  'objective': 'regression',
                  'metric': 'rmse',
                  'subsample': 0.75,
                  'subsample_freq': 1,
                  'learning_rate': 0.01,
                  'feature_fraction': 0.9,
                  'max_depth': 15,
                  'lambda_l1': 1,
                  'lambda_l2': 1,
                  'early_stopping_rounds': 100
                  }
        return params

    def set_params(self, ps={}):
        params = self.get_params()
        if 'subsample_freq' in ps:
            params['subsample_freq'] = int(ps['subsample_freq'])
            params['learning_rate'] = ps['learning_rate']
            params['feature_fraction'] = ps['feature_fraction']
            params['lambda_l1'] = ps['lambda_l1']
            params['lambda_l2'] = ps['lambda_l2']
            params['max_depth'] = int(ps['max_depth'])

        return params


class Rf_binary_Model(Base_Model):

    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return lgb.train(self.params, train_set, valid_sets=[train_set, val_set], verbose_eval=verbosity)

    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = lgb.Dataset(
            x_train, y_train, categorical_feature=self.categoricals)
        val_set = lgb.Dataset(
            x_val, y_val, categorical_feature=self.categoricals)
        return train_set, val_set

    def get_params(self):
        params = {'n_estimators': 5000,
                  'boosting_type': 'rf',
                  'objective': 'binary',
                  'metric': 'rmse',
                  'subsample': 0.75,
                  'subsample_freq': 1,
                  'learning_rate': 0.01,
                  'feature_fraction': 0.9,
                  'max_depth': 15,
                  'lambda_l1': 1,
                  'lambda_l2': 1,
                  'early_stopping_rounds': 100
                  }
        return params

    def set_params(self, ps={}):
        params = self.get_params()
        if 'subsample_freq' in ps:
            params['subsample_freq'] = int(ps['subsample_freq'])
            params['learning_rate'] = ps['learning_rate']
            params['feature_fraction'] = ps['feature_fraction']
            params['lambda_l1'] = ps['lambda_l1']
            params['lambda_l2'] = ps['lambda_l2']
            params['max_depth'] = int(ps['max_depth'])

        return params

# %%
class Xgb_regr_Model(Base_Model):

    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return xgb.train(self.params, train_set,
                         num_boost_round=5000, evals=[(train_set, 'train'), (val_set, 'val')],
                         verbose_eval=verbosity, early_stopping_rounds=100)

    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = xgb.DMatrix(x_train, y_train)
        val_set = xgb.DMatrix(x_val, y_val)
        return train_set, val_set

    def convert_x(self, x):
        return xgb.DMatrix(x)

    def get_params(self):
        params = {'colsample_bytree': 0.8,
                  'learning_rate': 0.01,
                  'max_depth': 10,
                  'subsample': 1,
                  'objective': 'reg:squarederror',
                  # 'eval_metric':'rmse',
                  'min_child_weight': 3,
                  'gamma': 0.25,
                  'n_estimators': 5000}
        return params

# %%
class Catb_regr_Model(Base_Model):

    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        clf = CatBoostRegressor(**self.params)
        clf.fit(train_set['X'],
                train_set['y'],
                eval_set=(val_set['X'], val_set['y']),
                verbose=verbosity,
                cat_features=self.categoricals)
        return clf

    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = {'X': x_train, 'y': y_train}
        val_set = {'X': x_val, 'y': y_val}
        return train_set, val_set

    def get_params(self):
        params = {'loss_function': 'RMSE',
                  'task_type': "CPU",
                  'iterations': 5000,
                  'od_type': "Iter",
                  'depth': 10,
                  'colsample_bylevel': 0.5,
                  'early_stopping_rounds': 300,
                  'l2_leaf_reg': 18,
                  'random_seed': 42,
                  'use_best_model': True
                  }
        return params

# %%
class Nn_Model(Base_Model):

    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True):
        features = features.copy()
        if len(categoricals) > 0:
            for cat in categoricals:
                enc = OneHotEncoder()
                train_cats = enc.fit_transform(train_df[[cat]])
                test_cats = enc.transform(test_df[[cat]])
                cat_cols = ['{}_{}'.format(cat, str(col))
                            for col in enc.active_features_]
                features += cat_cols
                train_cats = pd.DataFrame(
                    train_cats.toarray(), columns=cat_cols)
                test_cats = pd.DataFrame(test_cats.toarray(), columns=cat_cols)
                train_df = pd.concat([train_df, train_cats], axis=1)
                test_df = pd.concat([test_df, test_cats], axis=1)
        scalar = MinMaxScaler()
        train_df[features] = scalar.fit_transform(train_df[features])
        test_df[features] = scalar.transform(test_df[features])
        print(train_df[features].shape)
        super().__init__(train_df, test_df, features, categoricals, n_splits, verbose)

    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        model = tf.keras.models.Sequential([
            tf.keras.layers.Input(shape=(train_set['X'].shape[1],)),
            tf.keras.layers.Dense(200, activation='relu'),
            tf.keras.layers.LayerNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(100, activation='relu'),
            tf.keras.layers.LayerNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(50, activation='relu'),
            tf.keras.layers.LayerNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(25, activation='relu'),
            tf.keras.layers.LayerNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(1, activation='relu')
        ])
        model.compile(optimizer=tf.keras.optimizers.Adam(
            learning_rate=4e-4), loss='mse')
        print(model.summary())
        save_best = tf.keras.callbacks.ModelCheckpoint(
            'nn_model.w8', save_weights_only=True, save_best_only=True, verbose=1)
        early_stop = tf.keras.callbacks.EarlyStopping(patience=20)
        model.fit(train_set['X'],
                  train_set['y'],
                  validation_data=(val_set['X'], val_set['y']),
                  epochs=100,
                  callbacks=[save_best, early_stop])
        model.load_weights('nn_model.w8')
        return model

    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = {'X': x_train, 'y': y_train}
        val_set = {'X': x_val, 'y': y_val}
        return train_set, val_set

# %%
class Cnn_Model(Base_Model):

    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True):
        features = features.copy()
        if len(categoricals) > 0:
            for cat in categoricals:
                enc = OneHotEncoder()
                train_cats = enc.fit_transform(train_df[[cat]])
                test_cats = enc.transform(test_df[[cat]])
                cat_cols = ['{}_{}'.format(cat, str(col))
                            for col in enc.active_features_]
                features += cat_cols
                train_cats = pd.DataFrame(
                    train_cats.toarray(), columns=cat_cols)
                test_cats = pd.DataFrame(test_cats.toarray(), columns=cat_cols)
                train_df = pd.concat([train_df, train_cats], axis=1)
                test_df = pd.concat([test_df, test_cats], axis=1)
        scalar = MinMaxScaler()
        train_df[features] = scalar.fit_transform(train_df[features])
        test_df[features] = scalar.transform(test_df[features])
        self.create_feat_2d(features)
        super().__init__(train_df, test_df, features, categoricals, n_splits, verbose)

    def create_feat_2d(self, features, n_feats_repeat=50):
        self.n_feats = len(features)
        self.n_feats_repeat = n_feats_repeat
        self.mask = np.zeros(
            (self.n_feats_repeat, self.n_feats), dtype=np.int32)
        for i in range(self.n_feats_repeat):
            l = list(range(self.n_feats))
            for j in range(self.n_feats):
                c = l.pop(choice(range(len(l))))
                self.mask[i, j] = c
        self.mask = tf.convert_to_tensor(self.mask)
        print(self.mask.shape)

    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0

        inp = tf.keras.layers.Input(shape=(self.n_feats))
        x = tf.keras.layers.Lambda(
            lambda x: tf.gather(x, self.mask, axis=1))(inp)
        x = tf.keras.layers.Reshape((self.n_feats_repeat, self.n_feats, 1))(x)
        x = tf.keras.layers.Conv2D(
            18, (50, 50), strides=50, activation='relu')(x)
        x = tf.keras.layers.Flatten()(x)
        # x = tf.keras.layers.Dense(200, activation='relu')(x)
        # x = tf.keras.layers.LayerNormalization()(x)
        # x = tf.keras.layers.Dropout(0.3)(x)
        x = tf.keras.layers.Dense(100, activation='relu')(x)
        x = tf.keras.layers.LayerNormalization()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
        x = tf.keras.layers.Dense(50, activation='relu')(x)
        x = tf.keras.layers.LayerNormalization()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
        out = tf.keras.layers.Dense(1)(x)

        model = tf.keras.Model(inp, out)

        model.compile(optimizer=tf.keras.optimizers.Adam(
            learning_rate=1e-4), loss='mse')
        print(model.summary())
        save_best = tf.keras.callbacks.ModelCheckpoint(
            'nn_model.w8', save_weights_only=True, save_best_only=True, verbose=1)
        early_stop = tf.keras.callbacks.EarlyStopping(patience=20)
        model.fit(train_set['X'],
                  train_set['y'],
                  validation_data=(val_set['X'], val_set['y']),
                  epochs=100,
                  callbacks=[save_best, early_stop])
        model.load_weights('nn_model.w8')
        return model

    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = {'X': x_train, 'y': y_train}
        val_set = {'X': x_val, 'y': y_val}
        return train_set, val_set

# %%
class Wrapper_bayesOpt:

    def __init__(self, train, test, features, categoricals):
        self.train = train
        self.test = test
        self.features = features
        self.categoricals = categoricals

    def LGB_Beyes(self,
                  subsample_freq,
                  learning_rate,
                  feature_fraction,
                  max_depth,
                  lambda_l1,
                  lambda_l2):
        params = {}
        params['subsample_freq'] = subsample_freq
        params['learning_rate'] = learning_rate
        params['feature_fraction'] = feature_fraction
        params['lambda_l1'] = lambda_l1
        params['lambda_l2'] = lambda_l2
        params['max_depth'] = max_depth
        lgb_model = Lgb_regr_Model(self.train, self.test,
                                   self.features, categoricals=self.categoricals, ps=params)
        print('kappa: ', lgb_model.score)
        return lgb_model.score

    def fit(self, bounds_LGB):
        LGB_BO = BayesianOptimization(
            self.LGB_Beyes, bounds_LGB, random_state=1029)
        init_points = 16
        n_iter = 16
        with warnings.catch_warnings():
            warnings.filterwarnings('ignore')
            LGB_BO.maximize(init_points=init_points, n_iter=n_iter,
                            acq='ucb', xi=0.0, alpha=1e-6)
        return LGB_BO


class Adversarial_validator:

    def __init__(self, train, test, features, categoricals):
        self.train = train
        self.test = test
        self.features = features
        self.categoricals = categoricals
        self.clf = self.fit()

    def fit(self):
        self.train['target'] = 0
        self.test['target'] = 1
        self.union_df = pd.concat([self.train, self.test], axis=0)

        train, test = train_test_split(
            self.union_df, test_size=0.33, random_state=42, shuffle=True)
        clf = self.train_model(train, test)
        self.plot_feature_importance(clf)
        return clf

    def train_model(self, train, test):
        train_y = train['target'].values
        test_y = test['target'].values

        lgb_train = lgb.Dataset(train[self.features], label=train_y, categorical_feature=self.categoricals)
        lgb_test = lgb.Dataset(test[self.features], label=test_y, categorical_feature=self.categoricals)
        param = self.get_params()

        clf = lgb.train(param, lgb_train, valid_sets=[lgb_train, lgb_test])
        return clf

    def get_params(self):
        param = {'num_leaves': 50,
                 'num_round': 100,
                 'min_data_in_leaf': 30,
                 'objective': 'binary',
                 'max_depth': 5,
                 'learning_rate': 0.2,
                 'min_child_samples': 20,
                 'boosting': 'gbdt',
                 'feature_fraction': 0.9,
                 'bagging_freq': 1,
                 'bagging_fraction': 0.9,
                 'bagging_seed': 44,
                 'verbose_eval': 50,
                 'early_stopping_rounds': 50,
                 'metric': 'auc',
                 'verbosity': -1}
        return param

    def plot_feature_importance(self, clf):
        self.feature_importance = pd.DataFrame(zip(clf.feature_importance(), self.features), columns=['Value', 'Feature']).sort_values('Value', ascending=False).reset_index(drop=True)
        plt.figure(figsize=(20, 300))
        sns.barplot(x="Value", y="Feature", data=self.feature_importance.head(500))
        plt.title('LightGBM Features')
        plt.tight_layout()
        plt.show()


# DSB metric
def eval_qwk_lgb_regr(y_true, y_pred):
    """
    Fast cappa eval function for lgb.
    """
    dist = Counter(reduce_train['accuracy_group'])
    for k in dist:
        dist[k] /= len(reduce_train)
    reduce_train['accuracy_group'].hist()

    acum = 0
    bound = {}
    for i in range(3):
        acum += dist[i]
        bound[i] = np.percentile(y_pred, acum * 100)

    def classify(x):
        if x <= bound[0]:
            return 0
        elif x <= bound[1]:
            return 1
        elif x <= bound[2]:
            return 2
        else:
            return 3

    y_pred = np.array(list(map(classify, y_pred))).reshape(y_true.shape)

    return 'cappa', cohen_kappa_score(y_true, y_pred, weights='quadratic'), True

# %%
# read data
train, test, train_labels, specs, sample_submission = read_data()
# get usefull dict with maping encode
train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code = encode_title(train, test, train_labels)
# tranform function to get the train and test set
reduce_train, reduce_test, categoricals = get_train_and_test(train, test)
# Out:
# Reading train.csv file....

# %%
def stract_hists(feature, train=reduce_train, test=reduce_test, adjust=False, plot=False):
    n_bins = 10
    train_data = train[feature]
    test_data = test[feature]
    if adjust:
        test_data *= train_data.mean() / test_data.mean()
    perc_90 = np.percentile(train_data, 95)
    train_data = np.clip(train_data, 0, perc_90)
    test_data = np.clip(test_data, 0, perc_90)
    train_hist = np.histogram(train_data, bins=n_bins)[0] / len(train_data)
    test_hist = np.histogram(test_data, bins=n_bins)[0] / len(test_data)
    msre = mean_squared_error(train_hist, test_hist)
    if plot:
        print(msre)
        plt.bar(range(n_bins), train_hist, color='blue', alpha=0.5)
        plt.bar(range(n_bins), test_hist, color='red', alpha=0.5)
        plt.show()
    return msre
stract_hists('Magma Peak - Level 1_2000', adjust=False, plot=True)

# %%
# call feature engineering function
features = reduce_train.loc[(reduce_train.sum(axis=1) != 0), (reduce_train.sum(axis=0) != 0)].columns # delete useless columns
features = [x for x in features if x not in ['accuracy_group', 'installation_id']]

# %%
counter = 0
to_remove = []
for feat_a in features:
    for feat_b in features:
        if feat_a != feat_b and feat_a not in to_remove and feat_b not in to_remove:
            c = np.corrcoef(reduce_train[feat_a], reduce_train[feat_b])[0][1]
            if c > 0.995:
                counter += 1
                to_remove.append(feat_b)
                print('{}: FEAT_A: {} FEAT_B: {} - Correlation: {}'.format(counter, feat_a, feat_b, c))

# %%
to_exclude = [] 
ajusted_test = reduce_test.copy()
for feature in ajusted_test.columns:
    if feature not in ['accuracy_group', 'installation_id', 'accuracy_group', 'session_title']:
        data = reduce_train[feature]
        train_mean = data.mean()
        data = ajusted_test[feature] 
        test_mean = data.mean()
        try:
            error = stract_hists(feature, adjust=True)
            ajust_factor = train_mean / test_mean
            if ajust_factor > 10 or ajust_factor < 0.1:# or error > 0.01:
                to_exclude.append(feature)
                print(feature, train_mean, test_mean, error)
            else:
                ajusted_test[feature] *= ajust_factor
        except:
            to_exclude.append(feature)
            print(feature, train_mean, test_mean)

# %%
features = [x for x in features if x not in (to_exclude + to_remove)]
reduce_train[features].shape

# %%
print(reduce_train.shape,ajusted_test.shape)

# %%
clf = Adversarial_validator(reduce_train, ajusted_test, features, categoricals)
features = [x for x in features if x not in (clf.feature_importance['Feature'].iloc[0])]

# %%
clf = Adversarial_validator(reduce_train, ajusted_test, features, categoricals)
# Out:
# [1]	training's auc: 0.997079	valid_1's auc: 0.997331
# Training until validation scores don't improve for 50 rounds
# [2]	training's auc: 0.999797	valid_1's auc: 0.999725
# [3]	training's auc: 0.999849	valid_1's auc: 0.999785
# [4]	training's auc: 0.999968	valid_1's auc: 0.999931
# [5]	training's auc: 0.99998	valid_1's auc: 0.999929
# [6]	training's auc: 0.999987	valid_1's auc: 0.999968
# [7]	training's auc: 0.999992	valid_1's auc: 0.999981
# [8]	training's auc: 0.999996	valid_1's auc: 0.999994
# [9]	training's auc: 0.999998	valid_1's auc: 0.999993
# [10]	training's auc: 0.999998	valid_1's auc: 0.999996
# [11]	training's auc: 0.999999	valid_1's auc: 0.999997
# [12]	training's auc: 1	valid_1's auc: 0.999995
# [13]	training's auc: 1	valid_1's auc: 0.999996
# [14]	training's auc: 1	valid_1's auc: 0.999992
# [15]	training's auc: 1	valid_1's auc: 0.999992
# [16]	training's auc: 1	valid_1's auc: 0.999995
# [17]	training's auc: 1	valid_1's auc: 0.999995
# [18]	training's auc: 1	valid_1's auc: 0.999995
# [19]	training's auc: 1	valid_1's auc: 0.999996
# [20]	training's auc: 1	valid_1's auc: 0.999996
# [21]	training's auc: 1	valid_1's auc: 0.999997
# [22]	training's auc: 1	valid_1's auc: 0.999997
# [23]	training's auc: 1	valid_1's auc: 0.999998
# [24]	training's auc: 1	valid_1's auc: 0.999997
# [25]	training's auc: 1	valid_1's auc: 0.999998
# [26]	training's auc: 1	valid_1's auc: 0.999998
# [27]	training's auc: 1	valid_1's auc: 0.999998
# [28]	training's auc: 1	valid_1's auc: 0.999998
# [29]	training's auc: 1	valid_1's auc: 0.999998
# [30]	training's auc: 1	valid_1's auc: 0.999998
# [31]	training's auc: 1	valid_1's auc: 0.999998
# [32]	training's auc: 1	valid_1's auc: 0.999999
# [33]	training's auc: 1	valid_1's auc: 1
# [34]	training's auc: 1	valid_1's auc: 1
# [35]	training's auc: 1	valid_1's auc: 0.999999
# [36]	training's auc: 1	valid_1's auc: 1
# [37]	training's auc: 1	valid_1's auc: 1
# [38]	training's auc: 1	valid_1's auc: 1
# [39]	training's auc: 1	valid_1's auc: 1
# [40]	training's auc: 1	valid_1's auc: 1
# [41]	training's auc: 1	valid_1's auc: 1
# [42]	training's auc: 1	valid_1's auc: 1
# [43]	training's auc: 1	valid_1's auc: 1
# [44]	training's auc: 1	valid_1's auc: 1
# [45]	training's auc: 1	valid_1's auc: 1
# [46]	training's auc: 1	valid_1's auc: 1
# [47]	training's auc: 1	valid_1's auc: 1
# [48]	training's auc: 1	valid_1's auc: 1
# [49]	training's auc: 1	valid_1's auc: 1
# [50]	training's auc: 1	valid_1's auc: 1
# [51]	training's auc: 1	valid_1's auc: 1
# [52]	training's auc: 1	valid_1's auc: 1
# [53]	training's auc: 1	valid_1's auc: 1
# [54]	training's auc: 1	valid_1's auc: 1
# [55]	training's auc: 1	valid_1's auc: 1
# [56]	training's auc: 1	valid_1's auc: 1
# [57]	training's auc: 1	valid_1's auc: 1
# [58]	training's auc: 1	valid_1's auc: 1
# [59]	training's auc: 1	valid_1's auc: 1
# [60]	training's auc: 1	valid_1's auc: 1
# [61]	training's auc: 1	valid_1's auc: 1
# [62]	training's auc: 1	valid_1's auc: 1
# [63]	training's auc: 1	valid_1's auc: 1
# [64]	training's auc: 1	valid_1's auc: 1
# [65]	training's auc: 1	valid_1's auc: 1
# [66]	training's auc: 1	valid_1's auc: 1
# [67]	training's auc: 1	valid_1's auc: 1
# [68]	training's auc: 1	valid_1's auc: 1
# [69]	training's auc: 1	valid_1's auc: 1
# [70]	training's auc: 1	valid_1's auc: 1
# [71]	training's auc: 1	valid_1's auc: 1
# [72]	training's auc: 1	valid_1's auc: 1
# [73]	training's auc: 1	valid_1's auc: 1
# [74]	training's auc: 1	valid_1's auc: 1
# [75]	training's auc: 1	valid_1's auc: 1
# [76]	training's auc: 1	valid_1's auc: 1
# [77]	training's auc: 1	valid_1's auc: 1
# [78]	training's auc: 1	valid_1's auc: 1
# [79]	training's auc: 1	valid_1's auc: 1
# [80]	training's auc: 1	valid_1's auc: 1
# [81]	training's auc: 1	valid_1's auc: 1
# [82]	training's auc: 1	valid_1's auc: 1
# [83]	training's auc: 1	valid_1's auc: 1
# Early stopping, best iteration is:
# [33]	training's auc: 1	valid_1's auc: 1

# %%
bounds_LGB = {
    'subsample_freq': (1, 10),
    'learning_rate': (0.025, 0.5),
    'feature_fraction': (0.5, 1),
    'lambda_l1': (0, 5),
    'lambda_l2': (0, 5),
    'max_depth': (13, 17),
}

bo = Wrapper_bayesOpt(reduce_train, ajusted_test, features, categoricals)
LGB_BO = bo.fit(bounds_LGB)

replace_params = LGB_BO.max['params']
params = {'n_estimators': 5000,
                  'boosting_type': 'gbdt',
                  'objective': 'regression',
                  'metric': 'rmse',
                  'subsample': 0.75,
                  'subsample_freq': replace_params['subsample_freq'],
                  'learning_rate': replace_params['learning_rate'],
                  'feature_fraction': replace_params['feature_fraction'],
                  'max_depth': 15,
                  'lambda_l1': replace_params['lambda_l1'],
                  'lambda_l2': replace_params['lambda_l2'],
                  'early_stopping_rounds': 100
                  }
# Out:
# |   iter    |  target   | featur... | lambda_l1 | lambda_l2 | learni... | max_depth | subsam... |
# -------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.659212	valid_1's rmse: 1.05592
# Early stopping, best iteration is:
# [17]	training's rmse: 0.895845	valid_1's rmse: 1.01163
# Partial score of fold 0 is: 0.5654292044757365
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.65048	valid_1's rmse: 1.08299
# Early stopping, best iteration is:
# [12]	training's rmse: 0.923181	valid_1's rmse: 1.02876
# Partial score of fold 1 is: 0.5431803750694457
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.662454	valid_1's rmse: 1.06703
# Early stopping, best iteration is:
# [17]	training's rmse: 0.899294	valid_1's rmse: 1.01508
# Partial score of fold 2 is: 0.5642692387067656
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.659226	valid_1's rmse: 1.06754
# Early stopping, best iteration is:
# [12]	training's rmse: 0.919105	valid_1's rmse: 1.0224
# Partial score of fold 3 is: 0.5519481626219711
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.653658	valid_1's rmse: 1.06292
# Early stopping, best iteration is:
# [12]	training's rmse: 0.918629	valid_1's rmse: 1.01405
# Partial score of fold 4 is: 0.5684933768746867
# Our oof cohen kappa score is:  0.5582744229614418
# kappa:  0.5582744229614418
# |  1        |  0.5583   |  0.5205   |  2.049    |  2.944    |  0.4525   |  13.48    |  2.532    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.734034	valid_1's rmse: 1.00315
# Early stopping, best iteration is:
# [20]	training's rmse: 0.910708	valid_1's rmse: 0.987227
# Partial score of fold 0 is: 0.5874350537344786
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.727834	valid_1's rmse: 1.02508
# Early stopping, best iteration is:
# [18]	training's rmse: 0.915283	valid_1's rmse: 0.999967
# Partial score of fold 1 is: 0.5748517709224454
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.728528	valid_1's rmse: 1.0185
# Early stopping, best iteration is:
# [29]	training's rmse: 0.876553	valid_1's rmse: 0.994848
# Partial score of fold 2 is: 0.5850510339937505
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.730872	valid_1's rmse: 1.01177
# Early stopping, best iteration is:
# [19]	training's rmse: 0.912689	valid_1's rmse: 1.00017
# Partial score of fold 3 is: 0.5795040663584793
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.731682	valid_1's rmse: 1.01483
# Early stopping, best iteration is:
# [32]	training's rmse: 0.870476	valid_1's rmse: 0.996674
# Partial score of fold 4 is: 0.5790550407470757
# Our oof cohen kappa score is:  0.5805978828666889
# kappa:  0.5805978828666889
# |  2        |  0.5806   |  0.9701   |  2.977    |  1.678    |  0.2348   |  14.98    |  1.791    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.913512	valid_1's rmse: 0.983161
# [200]	training's rmse: 0.849519	valid_1's rmse: 0.975027
# [300]	training's rmse: 0.803706	valid_1's rmse: 0.97605
# Early stopping, best iteration is:
# [254]	training's rmse: 0.823855	valid_1's rmse: 0.974829
# Partial score of fold 0 is: 0.6040736226862102
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.909852	valid_1's rmse: 0.991323
# [200]	training's rmse: 0.84648	valid_1's rmse: 0.989021
# Early stopping, best iteration is:
# [198]	training's rmse: 0.847488	valid_1's rmse: 0.988798
# Partial score of fold 1 is: 0.5850510339937505
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.911169	valid_1's rmse: 0.991239
# [200]	training's rmse: 0.848783	valid_1's rmse: 0.985498
# [300]	training's rmse: 0.804536	valid_1's rmse: 0.986097
# Early stopping, best iteration is:
# [253]	training's rmse: 0.82369	valid_1's rmse: 0.984652
# Partial score of fold 2 is: 0.594713493745513
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.913876	valid_1's rmse: 0.995613
# [200]	training's rmse: 0.849718	valid_1's rmse: 0.98969
# [300]	training's rmse: 0.803985	valid_1's rmse: 0.987955
# Early stopping, best iteration is:
# [270]	training's rmse: 0.816499	valid_1's rmse: 0.9876
# Partial score of fold 3 is: 0.592387346027496
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.914595	valid_1's rmse: 0.992897
# [200]	training's rmse: 0.851069	valid_1's rmse: 0.983096
# [300]	training's rmse: 0.805533	valid_1's rmse: 0.982802
# Early stopping, best iteration is:
# [224]	training's rmse: 0.838929	valid_1's rmse: 0.981642
# Partial score of fold 4 is: 0.5874685695945719
# Our oof cohen kappa score is:  0.5923111288246463
# kappa:  0.5923111288246463
# |  3        |  0.5923   |  0.6371   |  3.3      |  0.4016   |  0.04336  |  15.7     |  2.686    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.711333	valid_1's rmse: 1.01573
# Early stopping, best iteration is:
# [17]	training's rmse: 0.912121	valid_1's rmse: 0.99302
# Partial score of fold 0 is: 0.5818888640839013
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.707191	valid_1's rmse: 1.03079
# Early stopping, best iteration is:
# [16]	training's rmse: 0.911395	valid_1's rmse: 1.00535
# Partial score of fold 1 is: 0.5760893086801949
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.713004	valid_1's rmse: 1.0269
# Early stopping, best iteration is:
# [16]	training's rmse: 0.912735	valid_1's rmse: 0.995722
# Partial score of fold 2 is: 0.5866614439523775
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.710991	valid_1's rmse: 1.02951
# Early stopping, best iteration is:
# [21]	training's rmse: 0.894624	valid_1's rmse: 0.999362
# Partial score of fold 3 is: 0.5875977994847112
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.709701	valid_1's rmse: 1.01994
# Early stopping, best iteration is:
# [20]	training's rmse: 0.896692	valid_1's rmse: 0.994258
# Partial score of fold 4 is: 0.5783389957387781
# Our oof cohen kappa score is:  0.5822898063833243
# kappa:  0.5822898063833243
# |  4        |  0.5823   |  0.9697   |  4.356    |  1.791    |  0.2947   |  16.52    |  5.072    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.786549	valid_1's rmse: 0.985671
# Early stopping, best iteration is:
# [45]	training's rmse: 0.873152	valid_1's rmse: 0.9785
# Partial score of fold 0 is: 0.598169614348499
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.783	valid_1's rmse: 1.0072
# Early stopping, best iteration is:
# [32]	training's rmse: 0.89829	valid_1's rmse: 0.996974
# Partial score of fold 1 is: 0.5748517709224454
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.787781	valid_1's rmse: 0.998279
# Early stopping, best iteration is:
# [49]	training's rmse: 0.865257	valid_1's rmse: 0.993253
# Partial score of fold 2 is: 0.5794411798001836
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.786306	valid_1's rmse: 1.00161
# Early stopping, best iteration is:
# [55]	training's rmse: 0.852817	valid_1's rmse: 0.995818
# Partial score of fold 3 is: 0.5877350505914622
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.786311	valid_1's rmse: 0.996241
# Early stopping, best iteration is:
# [55]	training's rmse: 0.854019	valid_1's rmse: 0.98968
# Partial score of fold 4 is: 0.5799500970074476
# Our oof cohen kappa score is:  0.5845088134953313
# kappa:  0.5845088134953313
# |  5        |  0.5845   |  0.8525   |  3.981    |  4.719    |  0.1693   |  16.64    |  5.5      |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.787021	valid_1's rmse: 0.99684
# Early stopping, best iteration is:
# [49]	training's rmse: 0.868897	valid_1's rmse: 0.990979
# Partial score of fold 0 is: 0.5752692183719219
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.781854	valid_1's rmse: 1.00686
# Early stopping, best iteration is:
# [51]	training's rmse: 0.859555	valid_1's rmse: 0.997051
# Partial score of fold 1 is: 0.5768200497607674
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.78638	valid_1's rmse: 1.00609
# Early stopping, best iteration is:
# [45]	training's rmse: 0.87762	valid_1's rmse: 0.995413
# Partial score of fold 2 is: 0.5850510339937505
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.781139	valid_1's rmse: 1.00049
# Early stopping, best iteration is:
# [48]	training's rmse: 0.867829	valid_1's rmse: 0.994997
# Partial score of fold 3 is: 0.5897033294297842
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.785192	valid_1's rmse: 1.00275
# Early stopping, best iteration is:
# [53]	training's rmse: 0.863394	valid_1's rmse: 0.995401
# Partial score of fold 4 is: 0.5779809732346294
# Our oof cohen kappa score is:  0.5802855418950599
# kappa:  0.5802855418950599
# |  6        |  0.5803   |  0.5194   |  1.336    |  0.582    |  0.1599   |  14.96    |  7.815    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.926152	valid_1's rmse: 0.983976
# [200]	training's rmse: 0.86708	valid_1's rmse: 0.976975
# [300]	training's rmse: 0.825246	valid_1's rmse: 0.976382
# [400]	training's rmse: 0.790108	valid_1's rmse: 0.974938
# [500]	training's rmse: 0.759708	valid_1's rmse: 0.976681
# Early stopping, best iteration is:
# [414]	training's rmse: 0.785535	valid_1's rmse: 0.974655
# Partial score of fold 0 is: 0.6008532545020042
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.922455	valid_1's rmse: 0.994343
# [200]	training's rmse: 0.864268	valid_1's rmse: 0.991109
# Early stopping, best iteration is:
# [168]	training's rmse: 0.880402	valid_1's rmse: 0.990779
# Partial score of fold 1 is: 0.5871982472719199
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.925142	valid_1's rmse: 0.992774
# [200]	training's rmse: 0.866565	valid_1's rmse: 0.986048
# [300]	training's rmse: 0.825508	valid_1's rmse: 0.988183
# Early stopping, best iteration is:
# [203]	training's rmse: 0.865013	valid_1's rmse: 0.985698
# Partial score of fold 2 is: 0.5909558705087163
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.923821	valid_1's rmse: 0.992726
# [200]	training's rmse: 0.86589	valid_1's rmse: 0.986746
# [300]	training's rmse: 0.823995	valid_1's rmse: 0.985563
# Early stopping, best iteration is:
# [291]	training's rmse: 0.827427	valid_1's rmse: 0.985414
# Partial score of fold 3 is: 0.5997236580612417
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.924972	valid_1's rmse: 0.992706
# [200]	training's rmse: 0.86789	valid_1's rmse: 0.983091
# [300]	training's rmse: 0.826363	valid_1's rmse: 0.982974
# Early stopping, best iteration is:
# [206]	training's rmse: 0.865029	valid_1's rmse: 0.982609
# Partial score of fold 4 is: 0.5885426371070183
# Our oof cohen kappa score is:  0.5932416801941975
# kappa:  0.5932416801941975
# |  7        |  0.5932   |  0.8534   |  2.64     |  4.351    |  0.03592  |  14.23    |  2.515    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.792324	valid_1's rmse: 0.991464
# Early stopping, best iteration is:
# [39]	training's rmse: 0.889936	valid_1's rmse: 0.988199
# Partial score of fold 0 is: 0.5892223481112382
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.788811	valid_1's rmse: 1.00563
# Early stopping, best iteration is:
# [31]	training's rmse: 0.904055	valid_1's rmse: 0.993993
# Partial score of fold 1 is: 0.5852299684335979
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.793649	valid_1's rmse: 1.0025
# Early stopping, best iteration is:
# [57]	training's rmse: 0.856947	valid_1's rmse: 0.994133
# Partial score of fold 2 is: 0.5832616895952758
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.788596	valid_1's rmse: 0.997067
# Early stopping, best iteration is:
# [45]	training's rmse: 0.875827	valid_1's rmse: 0.993949
# Partial score of fold 3 is: 0.5891665261102419
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.788828	valid_1's rmse: 0.993757
# Early stopping, best iteration is:
# [80]	training's rmse: 0.816287	valid_1's rmse: 0.99228
# Partial score of fold 4 is: 0.5783389957387781
# Our oof cohen kappa score is:  0.584651975244493
# kappa:  0.584651975244493
# |  8        |  0.5847   |  0.713    |  3.884    |  2.672    |  0.1635   |  14.89    |  7.059    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.768454	valid_1's rmse: 0.994233
# Early stopping, best iteration is:
# [26]	training's rmse: 0.908683	valid_1's rmse: 0.989485
# Partial score of fold 0 is: 0.578310677212561
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.764953	valid_1's rmse: 1.01787
# Early stopping, best iteration is:
# [22]	training's rmse: 0.917362	valid_1's rmse: 0.998355
# Partial score of fold 1 is: 0.582545951835886
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.767842	valid_1's rmse: 1.00354
# Early stopping, best iteration is:
# [30]	training's rmse: 0.895229	valid_1's rmse: 0.991359
# Partial score of fold 2 is: 0.5920294771478012
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.769117	valid_1's rmse: 1.0058
# Early stopping, best iteration is:
# [44]	training's rmse: 0.864996	valid_1's rmse: 0.999191
# Partial score of fold 3 is: 0.5818302140764962
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.767298	valid_1's rmse: 1.00757
# Early stopping, best iteration is:
# [51]	training's rmse: 0.847695	valid_1's rmse: 0.997257
# Partial score of fold 4 is: 0.5756538269576623
# Our oof cohen kappa score is:  0.5831129864410043
# kappa:  0.5831129864410043
# |  9        |  0.5831   |  0.6277   |  3.202    |  3.754    |  0.2022   |  13.63    |  9.341    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.771482	valid_1's rmse: 0.987164
# Early stopping, best iteration is:
# [83]	training's rmse: 0.795961	valid_1's rmse: 0.985674
# Partial score of fold 0 is: 0.5965594302563959
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.769129	valid_1's rmse: 1.01214
# Early stopping, best iteration is:
# [37]	training's rmse: 0.878726	valid_1's rmse: 1.00079
# Partial score of fold 1 is: 0.575030705362293
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.774158	valid_1's rmse: 1.00665
# Early stopping, best iteration is:
# [35]	training's rmse: 0.886612	valid_1's rmse: 0.993615
# Partial score of fold 2 is: 0.5827388659248105
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.765647	valid_1's rmse: 1.00139
# Early stopping, best iteration is:
# [38]	training's rmse: 0.874433	valid_1's rmse: 0.997206
# Partial score of fold 3 is: 0.5791461974787844
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.769864	valid_1's rmse: 1.00862
# Early stopping, best iteration is:
# [43]	training's rmse: 0.866786	valid_1's rmse: 0.998155
# Partial score of fold 4 is: 0.5693884331350587
# Our oof cohen kappa score is:  0.5799276375221555
# kappa:  0.5799276375221555
# |  10       |  0.5799   |  0.9993   |  0.5259   |  4.569    |  0.1726   |  14.9     |  9.381    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.628422	valid_1's rmse: 1.07802
# Early stopping, best iteration is:
# [6]	training's rmse: 0.956402	valid_1's rmse: 1.00696
# Partial score of fold 0 is: 0.5641768390707674
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.632597	valid_1's rmse: 1.081
# Early stopping, best iteration is:
# [5]	training's rmse: 0.961212	valid_1's rmse: 1.01339
# Partial score of fold 1 is: 0.5648201735648319
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.631514	valid_1's rmse: 1.07702
# Early stopping, best iteration is:
# [6]	training's rmse: 0.955029	valid_1's rmse: 1.01071
# Partial score of fold 2 is: 0.5591451981404287
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.626126	valid_1's rmse: 1.07773
# Early stopping, best iteration is:
# [12]	training's rmse: 0.907099	valid_1's rmse: 1.01542
# Partial score of fold 3 is: 0.5703928248217609
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.628977	valid_1's rmse: 1.07934
# Early stopping, best iteration is:
# [11]	training's rmse: 0.913918	valid_1's rmse: 1.01515
# Partial score of fold 4 is: 0.5628347676386407
# Our oof cohen kappa score is:  0.5643837451187571
# kappa:  0.5643837451187571
# |  11       |  0.5644   |  0.9364   |  0.2751   |  4.832    |  0.4788   |  13.28    |  5.325    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.786366	valid_1's rmse: 0.993027
# Early stopping, best iteration is:
# [59]	training's rmse: 0.849099	valid_1's rmse: 0.98939
# Partial score of fold 0 is: 0.5833201388324374
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.781118	valid_1's rmse: 1.0071
# Early stopping, best iteration is:
# [29]	training's rmse: 0.907627	valid_1's rmse: 1.00235
# Partial score of fold 1 is: 0.5719888198848861
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.784586	valid_1's rmse: 0.999143
# Early stopping, best iteration is:
# [32]	training's rmse: 0.901224	valid_1's rmse: 0.995103
# Partial score of fold 2 is: 0.5812934107569538
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.781975	valid_1's rmse: 0.999696
# Early stopping, best iteration is:
# [50]	training's rmse: 0.861419	valid_1's rmse: 0.992777
# Partial score of fold 3 is: 0.5861246406328351
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.787844	valid_1's rmse: 0.997743
# Early stopping, best iteration is:
# [64]	training's rmse: 0.840543	valid_1's rmse: 0.990579
# Partial score of fold 4 is: 0.583351310796861
# Our oof cohen kappa score is:  0.5816813689493869
# kappa:  0.5816813689493869
# |  12       |  0.5817   |  0.755    |  1.843    |  2.172    |  0.1569   |  14.26    |  6.525    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.710036	valid_1's rmse: 1.01311
# Early stopping, best iteration is:
# [21]	training's rmse: 0.897799	valid_1's rmse: 0.990473
# Partial score of fold 0 is: 0.5854670509552414
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.706794	valid_1's rmse: 1.03073
# Early stopping, best iteration is:
# [13]	training's rmse: 0.930531	valid_1's rmse: 1.00073
# Partial score of fold 1 is: 0.5709152132458014
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.715105	valid_1's rmse: 1.02604
# Early stopping, best iteration is:
# [18]	training's rmse: 0.909978	valid_1's rmse: 0.998997
# Partial score of fold 2 is: 0.5759253775615302
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.707327	valid_1's rmse: 1.01992
# Early stopping, best iteration is:
# [38]	training's rmse: 0.840997	valid_1's rmse: 1.00004
# Partial score of fold 3 is: 0.5768200497607674
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.711635	valid_1's rmse: 1.00981
# Early stopping, best iteration is:
# [29]	training's rmse: 0.870983	valid_1's rmse: 0.993016
# Partial score of fold 4 is: 0.5763698719659598
# Our oof cohen kappa score is:  0.5770329640624581
# kappa:  0.5770329640624581
# |  13       |  0.577    |  0.6994   |  1.488    |  3.371    |  0.2804   |  16.8     |  5.218    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.767398	valid_1's rmse: 0.998656
# Early stopping, best iteration is:
# [32]	training's rmse: 0.893179	valid_1's rmse: 0.988578
# Partial score of fold 0 is: 0.5852881416116744
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.760235	valid_1's rmse: 1.01539
# Early stopping, best iteration is:
# [23]	training's rmse: 0.916294	valid_1's rmse: 0.999813
# Partial score of fold 1 is: 0.5730624265239709
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.76925	valid_1's rmse: 1.00926
# Early stopping, best iteration is:
# [23]	training's rmse: 0.918182	valid_1's rmse: 0.996347
# Partial score of fold 2 is: 0.584872099553903
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.764515	valid_1's rmse: 1.00451
# Early stopping, best iteration is:
# [48]	training's rmse: 0.851869	valid_1's rmse: 0.999059
# Partial score of fold 3 is: 0.5895243949899367
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.763972	valid_1's rmse: 0.997866
# Early stopping, best iteration is:
# [45]	training's rmse: 0.859056	valid_1's rmse: 0.990512
# Partial score of fold 4 is: 0.5837093333010097
# Our oof cohen kappa score is:  0.5836498430003608
# kappa:  0.5836498430003608
# |  14       |  0.5836   |  0.6269   |  0.9706   |  4.516    |  0.1912   |  15.71    |  5.414    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.785493	valid_1's rmse: 0.994686
# Early stopping, best iteration is:
# [40]	training's rmse: 0.88565	valid_1's rmse: 0.988874
# Partial score of fold 0 is: 0.5861355932606238
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.778926	valid_1's rmse: 1.00936
# Early stopping, best iteration is:
# [46]	training's rmse: 0.866758	valid_1's rmse: 0.996983
# Partial score of fold 1 is: 0.5759253775615302
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.785444	valid_1's rmse: 0.994872
# Early stopping, best iteration is:
# [54]	training's rmse: 0.855154	valid_1's rmse: 0.990692
# Partial score of fold 2 is: 0.5855878373132928
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.7832	valid_1's rmse: 0.998222
# Early stopping, best iteration is:
# [64]	training's rmse: 0.836284	valid_1's rmse: 0.994976
# Partial score of fold 3 is: 0.5812934107569538
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.786532	valid_1's rmse: 0.992412
# Early stopping, best iteration is:
# [51]	training's rmse: 0.862175	valid_1's rmse: 0.987275
# Partial score of fold 4 is: 0.5923018734005805
# Our oof cohen kappa score is:  0.5843656517461695
# kappa:  0.5843656517461695
# |  15       |  0.5844   |  0.853    |  1.536    |  0.4828   |  0.1487   |  14.28    |  7.365    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.703292	valid_1's rmse: 1.02486
# Early stopping, best iteration is:
# [26]	training's rmse: 0.877927	valid_1's rmse: 0.999775
# Partial score of fold 0 is: 0.5706175754391798
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.701529	valid_1's rmse: 1.04368
# Early stopping, best iteration is:
# [18]	training's rmse: 0.905679	valid_1's rmse: 1.00445
# Partial score of fold 1 is: 0.5739570987232081
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.70396	valid_1's rmse: 1.03205
# Early stopping, best iteration is:
# [18]	training's rmse: 0.908906	valid_1's rmse: 1.00536
# Partial score of fold 2 is: 0.5780725908396996
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.703005	valid_1's rmse: 1.02522
# Early stopping, best iteration is:
# [19]	training's rmse: 0.901008	valid_1's rmse: 0.995937
# Partial score of fold 3 is: 0.5859457061929877
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.703607	valid_1's rmse: 1.02301
# Early stopping, best iteration is:
# [17]	training's rmse: 0.910968	valid_1's rmse: 0.994129
# Partial score of fold 4 is: 0.5747587706972903
# Our oof cohen kappa score is:  0.5766349172914353
# kappa:  0.5766349172914353
# |  16       |  0.5766   |  0.6327   |  1.826    |  1.33     |  0.2994   |  14.77    |  7.747    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.95603	valid_1's rmse: 0.997459
# [200]	training's rmse: 0.900327	valid_1's rmse: 0.978767
# [300]	training's rmse: 0.865306	valid_1's rmse: 0.977109
# [400]	training's rmse: 0.836405	valid_1's rmse: 0.975937
# Early stopping, best iteration is:
# [376]	training's rmse: 0.843041	valid_1's rmse: 0.975796
# Partial score of fold 0 is: 0.5990641610663341
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.953689	valid_1's rmse: 1.00248
# [200]	training's rmse: 0.897102	valid_1's rmse: 0.991012
# Early stopping, best iteration is:
# [191]	training's rmse: 0.900943	valid_1's rmse: 0.990594
# Partial score of fold 1 is: 0.5821880829561912
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.954806	valid_1's rmse: 1.00267
# [200]	training's rmse: 0.898661	valid_1's rmse: 0.988539
# [300]	training's rmse: 0.86339	valid_1's rmse: 0.988119
# Early stopping, best iteration is:
# [236]	training's rmse: 0.885062	valid_1's rmse: 0.987407
# Partial score of fold 2 is: 0.5882718539110046
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.954341	valid_1's rmse: 1.0063
# [200]	training's rmse: 0.898339	valid_1's rmse: 0.98953
# [300]	training's rmse: 0.863119	valid_1's rmse: 0.987476
# [400]	training's rmse: 0.834317	valid_1's rmse: 0.98738
# Early stopping, best iteration is:
# [360]	training's rmse: 0.845583	valid_1's rmse: 0.986763
# Partial score of fold 3 is: 0.5905980016290215
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.954803	valid_1's rmse: 1.00464
# [200]	training's rmse: 0.898848	valid_1's rmse: 0.98624
# [300]	training's rmse: 0.863969	valid_1's rmse: 0.983047
# [400]	training's rmse: 0.835768	valid_1's rmse: 0.982087
# Early stopping, best iteration is:
# [376]	training's rmse: 0.84213	valid_1's rmse: 0.981983
# Partial score of fold 4 is: 0.5878265920987207
# Our oof cohen kappa score is:  0.5895552651532827
# kappa:  0.5895552651532827
# |  17       |  0.5896   |  0.748    |  4.936    |  0.3949   |  0.02599  |  16.3     |  9.951    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.802172	valid_1's rmse: 0.986595
# Early stopping, best iteration is:
# [58]	training's rmse: 0.85987	valid_1's rmse: 0.980753
# Partial score of fold 0 is: 0.5923548501748302
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.800068	valid_1's rmse: 1.00238
# Early stopping, best iteration is:
# [33]	training's rmse: 0.905583	valid_1's rmse: 0.994387
# Partial score of fold 1 is: 0.5771779186404624
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.798971	valid_1's rmse: 0.99429
# Early stopping, best iteration is:
# [74]	training's rmse: 0.83379	valid_1's rmse: 0.992364
# Partial score of fold 2 is: 0.5852299684335979
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.799457	valid_1's rmse: 0.992391
# Early stopping, best iteration is:
# [72]	training's rmse: 0.836319	valid_1's rmse: 0.991806
# Partial score of fold 3 is: 0.5855878373132928
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.80028	valid_1's rmse: 0.99735
# Early stopping, best iteration is:
# [41]	training's rmse: 0.88973	valid_1's rmse: 0.991374
# Partial score of fold 4 is: 0.5815611982761171
# Our oof cohen kappa score is:  0.585296203115721
# kappa:  0.585296203115721
# |  18       |  0.5853   |  0.7379   |  4.696    |  4.5      |  0.1552   |  16.84    |  1.129    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.917531	valid_1's rmse: 0.980288
# [200]	training's rmse: 0.856869	valid_1's rmse: 0.974752
# [300]	training's rmse: 0.812651	valid_1's rmse: 0.976431
# Early stopping, best iteration is:
# [213]	training's rmse: 0.850891	valid_1's rmse: 0.974291
# Partial score of fold 0 is: 0.6033579853119423
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.91269	valid_1's rmse: 0.989869
# [200]	training's rmse: 0.853708	valid_1's rmse: 0.987693
# Early stopping, best iteration is:
# [169]	training's rmse: 0.869317	valid_1's rmse: 0.98707
# Partial score of fold 1 is: 0.5857667717531403
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.916022	valid_1's rmse: 0.991778
# [200]	training's rmse: 0.856288	valid_1's rmse: 0.986135
# Early stopping, best iteration is:
# [196]	training's rmse: 0.858261	valid_1's rmse: 0.985976
# Partial score of fold 2 is: 0.5905980016290215
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.913651	valid_1's rmse: 0.990425
# [200]	training's rmse: 0.854818	valid_1's rmse: 0.985596
# [300]	training's rmse: 0.809748	valid_1's rmse: 0.985246
# Early stopping, best iteration is:
# [262]	training's rmse: 0.825479	valid_1's rmse: 0.984514
# Partial score of fold 3 is: 0.5959660348244451
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.915538	valid_1's rmse: 0.989715
# [200]	training's rmse: 0.856393	valid_1's rmse: 0.982961
# [300]	training's rmse: 0.812405	valid_1's rmse: 0.983389
# Early stopping, best iteration is:
# [248]	training's rmse: 0.833433	valid_1's rmse: 0.98169
# Partial score of fold 4 is: 0.5871105470904232
# Our oof cohen kappa score is:  0.5922395479500654
# kappa:  0.5922395479500654
# |  19       |  0.5922   |  0.9298   |  4.504    |  0.1819   |  0.04096  |  13.23    |  5.472    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.925617	valid_1's rmse: 0.983962
# [200]	training's rmse: 0.866399	valid_1's rmse: 0.975744
# [300]	training's rmse: 0.823168	valid_1's rmse: 0.975499
# Early stopping, best iteration is:
# [273]	training's rmse: 0.8338	valid_1's rmse: 0.974789
# Partial score of fold 0 is: 0.5990641610663341
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.921955	valid_1's rmse: 0.994032
# [200]	training's rmse: 0.863168	valid_1's rmse: 0.99181
# Early stopping, best iteration is:
# [167]	training's rmse: 0.879634	valid_1's rmse: 0.99141
# Partial score of fold 1 is: 0.5800408696780217
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.924204	valid_1's rmse: 0.993475
# [200]	training's rmse: 0.864477	valid_1's rmse: 0.9861
# Early stopping, best iteration is:
# [199]	training's rmse: 0.864935	valid_1's rmse: 0.986049
# Partial score of fold 2 is: 0.5871982472719199
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.923742	valid_1's rmse: 0.993605
# [200]	training's rmse: 0.864462	valid_1's rmse: 0.985566
# [300]	training's rmse: 0.822455	valid_1's rmse: 0.985272
# Early stopping, best iteration is:
# [251]	training's rmse: 0.84168	valid_1's rmse: 0.98466
# Partial score of fold 3 is: 0.5941766904259707
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.924904	valid_1's rmse: 0.99413
# [200]	training's rmse: 0.865307	valid_1's rmse: 0.98399
# [300]	training's rmse: 0.82196	valid_1's rmse: 0.983618
# [400]	training's rmse: 0.786804	valid_1's rmse: 0.983363
# Early stopping, best iteration is:
# [373]	training's rmse: 0.795742	valid_1's rmse: 0.983018
# Partial score of fold 4 is: 0.5862154908300512
# Our oof cohen kappa score is:  0.5909510922076098
# kappa:  0.5909510922076098
# |  20       |  0.591    |  0.9975   |  0.3251   |  3.817    |  0.03345  |  16.98    |  1.318    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.910092	valid_1's rmse: 0.982729
# [200]	training's rmse: 0.846549	valid_1's rmse: 0.977752
# [300]	training's rmse: 0.80219	valid_1's rmse: 0.979908
# Early stopping, best iteration is:
# [217]	training's rmse: 0.838271	valid_1's rmse: 0.977368
# Partial score of fold 0 is: 0.5994219797534681
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.906006	valid_1's rmse: 0.994281
# [200]	training's rmse: 0.843934	valid_1's rmse: 0.996204
# Early stopping, best iteration is:
# [100]	training's rmse: 0.906006	valid_1's rmse: 0.994281
# Partial score of fold 1 is: 0.5809355418772589
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.909457	valid_1's rmse: 0.991112
# [200]	training's rmse: 0.846202	valid_1's rmse: 0.986447
# [300]	training's rmse: 0.799347	valid_1's rmse: 0.989121
# Early stopping, best iteration is:
# [204]	training's rmse: 0.844147	valid_1's rmse: 0.98632
# Partial score of fold 2 is: 0.5905980016290215
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.908479	valid_1's rmse: 0.992881
# [200]	training's rmse: 0.846481	valid_1's rmse: 0.987837
# [300]	training's rmse: 0.801282	valid_1's rmse: 0.988256
# Early stopping, best iteration is:
# [289]	training's rmse: 0.805682	valid_1's rmse: 0.987034
# Partial score of fold 3 is: 0.5973975103432247
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.908806	valid_1's rmse: 0.988766
# [200]	training's rmse: 0.846175	valid_1's rmse: 0.983303
# [300]	training's rmse: 0.800511	valid_1's rmse: 0.98313
# Early stopping, best iteration is:
# [232]	training's rmse: 0.830632	valid_1's rmse: 0.98229
# Partial score of fold 4 is: 0.5869315358383488
# Our oof cohen kappa score is:  0.5902710738990915
# kappa:  0.5902710738990915
# |  21       |  0.5903   |  0.7275   |  4.57     |  0.01088  |  0.04646  |  13.42    |  9.794    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.933206	valid_1's rmse: 0.98419
# [200]	training's rmse: 0.878013	valid_1's rmse: 0.97453
# [300]	training's rmse: 0.838753	valid_1's rmse: 0.974043
# Early stopping, best iteration is:
# [239]	training's rmse: 0.861365	valid_1's rmse: 0.973709
# Partial score of fold 0 is: 0.6031790759683753
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.928614	valid_1's rmse: 0.996591
# [200]	training's rmse: 0.874757	valid_1's rmse: 0.991825
# [300]	training's rmse: 0.835269	valid_1's rmse: 0.993167
# Early stopping, best iteration is:
# [208]	training's rmse: 0.870951	valid_1's rmse: 0.991412
# Partial score of fold 1 is: 0.5855878373132928
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.930457	valid_1's rmse: 0.994477
# [200]	training's rmse: 0.875098	valid_1's rmse: 0.986872
# [300]	training's rmse: 0.837168	valid_1's rmse: 0.987121
# Early stopping, best iteration is:
# [219]	training's rmse: 0.867231	valid_1's rmse: 0.986372
# Partial score of fold 2 is: 0.5897033294297842
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.930356	valid_1's rmse: 0.995098
# [200]	training's rmse: 0.875896	valid_1's rmse: 0.989416
# [300]	training's rmse: 0.836591	valid_1's rmse: 0.987865
# [400]	training's rmse: 0.804308	valid_1's rmse: 0.987532
# Early stopping, best iteration is:
# [380]	training's rmse: 0.810097	valid_1's rmse: 0.987184
# Partial score of fold 3 is: 0.5973975103432247
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.93088	valid_1's rmse: 0.99423
# [200]	training's rmse: 0.87633	valid_1's rmse: 0.985521
# [300]	training's rmse: 0.837701	valid_1's rmse: 0.984827
# [400]	training's rmse: 0.805305	valid_1's rmse: 0.985585
# Early stopping, best iteration is:
# [322]	training's rmse: 0.830244	valid_1's rmse: 0.984343
# Partial score of fold 4 is: 0.5853204345696793
# Our oof cohen kappa score is:  0.5913447870178046
# kappa:  0.5913447870178046
# |  22       |  0.5913   |  0.9257   |  4.933    |  4.662    |  0.03478  |  13.39    |  4.601    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.868946	valid_1's rmse: 0.979491
# [200]	training's rmse: 0.791492	valid_1's rmse: 0.980687
# Early stopping, best iteration is:
# [138]	training's rmse: 0.836012	valid_1's rmse: 0.978391
# Partial score of fold 0 is: 0.5977233113226595
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.865775	valid_1's rmse: 0.989149
# Early stopping, best iteration is:
# [87]	training's rmse: 0.877927	valid_1's rmse: 0.988655
# Partial score of fold 1 is: 0.5871982472719199
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.866517	valid_1's rmse: 0.990053
# [200]	training's rmse: 0.791643	valid_1's rmse: 0.991742
# Early stopping, best iteration is:
# [113]	training's rmse: 0.855024	valid_1's rmse: 0.989375
# Partial score of fold 2 is: 0.5846931651140554
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.86694	valid_1's rmse: 0.986515
# [200]	training's rmse: 0.790127	valid_1's rmse: 0.985974
# Early stopping, best iteration is:
# [142]	training's rmse: 0.831859	valid_1's rmse: 0.984239
# Partial score of fold 3 is: 0.5914926738282588
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.867827	valid_1's rmse: 0.984813
# [200]	training's rmse: 0.791798	valid_1's rmse: 0.98571
# Early stopping, best iteration is:
# [149]	training's rmse: 0.826992	valid_1's rmse: 0.984445
# Partial score of fold 4 is: 0.5885426371070183
# Our oof cohen kappa score is:  0.5887678755328931
# kappa:  0.5887678755328931
# |  23       |  0.5888   |  0.9639   |  3.843    |  0.1441   |  0.06985  |  16.68    |  1.088    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.923755	valid_1's rmse: 0.982036
# [200]	training's rmse: 0.86381	valid_1's rmse: 0.973966
# [300]	training's rmse: 0.819612	valid_1's rmse: 0.974066
# Early stopping, best iteration is:
# [221]	training's rmse: 0.853809	valid_1's rmse: 0.972989
# Partial score of fold 0 is: 0.6042525320297774
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.91842	valid_1's rmse: 0.992621
# [200]	training's rmse: 0.860202	valid_1's rmse: 0.990356
# Early stopping, best iteration is:
# [169]	training's rmse: 0.875951	valid_1's rmse: 0.989293
# Partial score of fold 1 is: 0.5863035750726826
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.920779	valid_1's rmse: 0.991407
# [200]	training's rmse: 0.86091	valid_1's rmse: 0.985765
# Early stopping, best iteration is:
# [176]	training's rmse: 0.872897	valid_1's rmse: 0.98542
# Partial score of fold 2 is: 0.5886297227906995
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.920361	valid_1's rmse: 0.993075
# [200]	training's rmse: 0.86161	valid_1's rmse: 0.988979
# [300]	training's rmse: 0.817093	valid_1's rmse: 0.988218
# Early stopping, best iteration is:
# [240]	training's rmse: 0.842413	valid_1's rmse: 0.987863
# Partial score of fold 3 is: 0.5948924281853605
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.920839	valid_1's rmse: 0.993871
# [200]	training's rmse: 0.862393	valid_1's rmse: 0.985059
# [300]	training's rmse: 0.818988	valid_1's rmse: 0.98601
# Early stopping, best iteration is:
# [233]	training's rmse: 0.846948	valid_1's rmse: 0.98439
# Partial score of fold 4 is: 0.5863945020821256
# Our oof cohen kappa score is:  0.5905931878347054
# kappa:  0.5905931878347054
# |  24       |  0.5906   |  0.9876   |  2.446    |  0.1512   |  0.03557  |  16.98    |  5.739    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.923994	valid_1's rmse: 0.982335
# [200]	training's rmse: 0.867121	valid_1's rmse: 0.975455
# Early stopping, best iteration is:
# [193]	training's rmse: 0.870458	valid_1's rmse: 0.975145
# Partial score of fold 0 is: 0.6006743451584371
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.921115	valid_1's rmse: 0.992355
# [200]	training's rmse: 0.864616	valid_1's rmse: 0.990689
# Early stopping, best iteration is:
# [147]	training's rmse: 0.89098	valid_1's rmse: 0.990229
# Partial score of fold 1 is: 0.5818302140764962
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.9238	valid_1's rmse: 0.991231
# [200]	training's rmse: 0.867396	valid_1's rmse: 0.985624
# [300]	training's rmse: 0.826833	valid_1's rmse: 0.98703
# Early stopping, best iteration is:
# [236]	training's rmse: 0.851918	valid_1's rmse: 0.985299
# Partial score of fold 2 is: 0.5939977559861231
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.92348	valid_1's rmse: 0.99156
# [200]	training's rmse: 0.866762	valid_1's rmse: 0.985898
# [300]	training's rmse: 0.8259	valid_1's rmse: 0.984402
# Early stopping, best iteration is:
# [278]	training's rmse: 0.834157	valid_1's rmse: 0.983868
# Partial score of fold 3 is: 0.5950713626252079
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.92229	valid_1's rmse: 0.991011
# [200]	training's rmse: 0.867239	valid_1's rmse: 0.985137
# [300]	training's rmse: 0.826749	valid_1's rmse: 0.984811
# Early stopping, best iteration is:
# [243]	training's rmse: 0.848272	valid_1's rmse: 0.984052
# Partial score of fold 4 is: 0.5853204345696793
# Our oof cohen kappa score is:  0.5920248053263228
# kappa:  0.5920248053263228
# |  25       |  0.592    |  0.937    |  4.852    |  4.498    |  0.03876  |  13.64    |  9.533    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.894122	valid_1's rmse: 0.97782
# [200]	training's rmse: 0.827086	valid_1's rmse: 0.977556
# Early stopping, best iteration is:
# [133]	training's rmse: 0.868622	valid_1's rmse: 0.976382
# Partial score of fold 0 is: 0.5935179714157568
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.889596	valid_1's rmse: 0.993271
# [200]	training's rmse: 0.822734	valid_1's rmse: 0.99569
# Early stopping, best iteration is:
# [101]	training's rmse: 0.888692	valid_1's rmse: 0.992987
# Partial score of fold 1 is: 0.5803987385577165
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.892116	valid_1's rmse: 0.99064
# [200]	training's rmse: 0.826324	valid_1's rmse: 0.990016
# Early stopping, best iteration is:
# [138]	training's rmse: 0.86393	valid_1's rmse: 0.988322
# Partial score of fold 2 is: 0.584811273852002
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.892793	valid_1's rmse: 0.987442
# [200]	training's rmse: 0.82505	valid_1's rmse: 0.98608
# Early stopping, best iteration is:
# [170]	training's rmse: 0.843535	valid_1's rmse: 0.985766
# Partial score of fold 3 is: 0.5973975103432247
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.892977	valid_1's rmse: 0.987599
# [200]	training's rmse: 0.826548	valid_1's rmse: 0.98371
# [300]	training's rmse: 0.776305	valid_1's rmse: 0.985537
# Early stopping, best iteration is:
# [213]	training's rmse: 0.81913	valid_1's rmse: 0.982947
# Partial score of fold 4 is: 0.5869315358383488
# Our oof cohen kappa score is:  0.5898057982143158
# kappa:  0.5898057982143158
# |  26       |  0.5898   |  0.9977   |  2.091    |  4.998    |  0.05313  |  16.23    |  3.418    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944794	valid_1's rmse: 0.989146
# [200]	training's rmse: 0.89093	valid_1's rmse: 0.977156
# [300]	training's rmse: 0.853805	valid_1's rmse: 0.974593
# [400]	training's rmse: 0.823171	valid_1's rmse: 0.974117
# [500]	training's rmse: 0.796549	valid_1's rmse: 0.974636
# Early stopping, best iteration is:
# [467]	training's rmse: 0.805024	valid_1's rmse: 0.973828
# Partial score of fold 0 is: 0.6015688918762722
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.941169	valid_1's rmse: 0.998394
# [200]	training's rmse: 0.887059	valid_1's rmse: 0.991429
# [300]	training's rmse: 0.849608	valid_1's rmse: 0.989768
# [400]	training's rmse: 0.819064	valid_1's rmse: 0.990248
# Early stopping, best iteration is:
# [320]	training's rmse: 0.843051	valid_1's rmse: 0.989554
# Partial score of fold 1 is: 0.5871982472719199
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943101	valid_1's rmse: 0.997172
# [200]	training's rmse: 0.888735	valid_1's rmse: 0.985435
# [300]	training's rmse: 0.852284	valid_1's rmse: 0.984687
# [400]	training's rmse: 0.822072	valid_1's rmse: 0.98412
# [500]	training's rmse: 0.795709	valid_1's rmse: 0.985032
# Early stopping, best iteration is:
# [402]	training's rmse: 0.821446	valid_1's rmse: 0.984021
# Partial score of fold 2 is: 0.5929241493470384
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.941869	valid_1's rmse: 0.997623
# [200]	training's rmse: 0.887714	valid_1's rmse: 0.987387
# [300]	training's rmse: 0.850948	valid_1's rmse: 0.985771
# [400]	training's rmse: 0.820501	valid_1's rmse: 0.986406
# Early stopping, best iteration is:
# [316]	training's rmse: 0.84576	valid_1's rmse: 0.985694
# Partial score of fold 3 is: 0.592387346027496
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942916	valid_1's rmse: 0.99857
# [200]	training's rmse: 0.88869	valid_1's rmse: 0.984022
# [300]	training's rmse: 0.852317	valid_1's rmse: 0.980962
# [400]	training's rmse: 0.822123	valid_1's rmse: 0.980254
# Early stopping, best iteration is:
# [364]	training's rmse: 0.832515	valid_1's rmse: 0.97986
# Partial score of fold 4 is: 0.5874685695945719
# Our oof cohen kappa score is:  0.5920605957636133
# kappa:  0.5920605957636133
# |  27       |  0.5921   |  0.9557   |  4.742    |  1.332    |  0.02805  |  15.46    |  1.244    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.945954	valid_1's rmse: 0.993354
# [200]	training's rmse: 0.889782	valid_1's rmse: 0.976962
# [300]	training's rmse: 0.852406	valid_1's rmse: 0.973862
# [400]	training's rmse: 0.821787	valid_1's rmse: 0.973353
# [500]	training's rmse: 0.795286	valid_1's rmse: 0.974982
# Early stopping, best iteration is:
# [409]	training's rmse: 0.819167	valid_1's rmse: 0.973231
# Partial score of fold 0 is: 0.6010321638455711
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943144	valid_1's rmse: 1.00029
# [200]	training's rmse: 0.887013	valid_1's rmse: 0.990707
# Early stopping, best iteration is:
# [191]	training's rmse: 0.890891	valid_1's rmse: 0.990547
# Partial score of fold 1 is: 0.5837984929148182
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944168	valid_1's rmse: 0.99852
# [200]	training's rmse: 0.888517	valid_1's rmse: 0.987113
# [300]	training's rmse: 0.851569	valid_1's rmse: 0.986588
# Early stopping, best iteration is:
# [240]	training's rmse: 0.872238	valid_1's rmse: 0.986049
# Partial score of fold 2 is: 0.5922084115876486
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.946984	valid_1's rmse: 1.00512
# [200]	training's rmse: 0.888454	valid_1's rmse: 0.989276
# [300]	training's rmse: 0.851312	valid_1's rmse: 0.986404
# [400]	training's rmse: 0.82062	valid_1's rmse: 0.986403
# Early stopping, best iteration is:
# [335]	training's rmse: 0.840039	valid_1's rmse: 0.985847
# Partial score of fold 3 is: 0.5956081659447503
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.94768	valid_1's rmse: 1.00184
# [200]	training's rmse: 0.890063	valid_1's rmse: 0.98482
# [300]	training's rmse: 0.852588	valid_1's rmse: 0.98112
# [400]	training's rmse: 0.822189	valid_1's rmse: 0.980387
# Early stopping, best iteration is:
# [374]	training's rmse: 0.829557	valid_1's rmse: 0.980191
# Partial score of fold 4 is: 0.5923018734005805
# Our oof cohen kappa score is:  0.5926332427602602
# kappa:  0.5926332427602602
# |  28       |  0.5926   |  0.6525   |  4.874    |  4.886    |  0.03107  |  14.01    |  1.0      |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.895668	valid_1's rmse: 0.979715
# [200]	training's rmse: 0.826848	valid_1's rmse: 0.97659
# Early stopping, best iteration is:
# [177]	training's rmse: 0.840424	valid_1's rmse: 0.976136
# Partial score of fold 0 is: 0.5987063423792001
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.891453	valid_1's rmse: 0.991946
# [200]	training's rmse: 0.824608	valid_1's rmse: 0.990037
# Early stopping, best iteration is:
# [168]	training's rmse: 0.842775	valid_1's rmse: 0.989517
# Partial score of fold 1 is: 0.5875561161516147
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.892846	valid_1's rmse: 0.992626
# [200]	training's rmse: 0.826856	valid_1's rmse: 0.992515
# Early stopping, best iteration is:
# [157]	training's rmse: 0.85154	valid_1's rmse: 0.991665
# Partial score of fold 2 is: 0.5843352962343606
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.893044	valid_1's rmse: 0.993447
# [200]	training's rmse: 0.826067	valid_1's rmse: 0.991683
# Early stopping, best iteration is:
# [163]	training's rmse: 0.84754	valid_1's rmse: 0.990233
# Partial score of fold 3 is: 0.5884507883508521
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.895527	valid_1's rmse: 0.989301
# [200]	training's rmse: 0.828565	valid_1's rmse: 0.984136
# [300]	training's rmse: 0.780529	valid_1's rmse: 0.986512
# Early stopping, best iteration is:
# [208]	training's rmse: 0.824238	valid_1's rmse: 0.9838
# Partial score of fold 4 is: 0.5869315358383488
# Our oof cohen kappa score is:  0.5890184085939262
# kappa:  0.5890184085939262
# |  29       |  0.589    |  0.6911   |  4.951    |  0.08518  |  0.05646  |  16.8     |  4.719    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.921808	valid_1's rmse: 0.984776
# [200]	training's rmse: 0.859946	valid_1's rmse: 0.976129
# [300]	training's rmse: 0.814946	valid_1's rmse: 0.976001
# Early stopping, best iteration is:
# [262]	training's rmse: 0.830615	valid_1's rmse: 0.975241
# Partial score of fold 0 is: 0.599243070409901
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.917777	valid_1's rmse: 0.993657
# [200]	training's rmse: 0.856594	valid_1's rmse: 0.991206
# [300]	training's rmse: 0.811901	valid_1's rmse: 0.991848
# Early stopping, best iteration is:
# [238]	training's rmse: 0.838393	valid_1's rmse: 0.99097
# Partial score of fold 1 is: 0.582903820715581
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.920148	valid_1's rmse: 0.99356
# [200]	training's rmse: 0.858454	valid_1's rmse: 0.988381
# Early stopping, best iteration is:
# [198]	training's rmse: 0.859477	valid_1's rmse: 0.988183
# Partial score of fold 2 is: 0.5839774273546656
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.919413	valid_1's rmse: 0.993758
# [200]	training's rmse: 0.8581	valid_1's rmse: 0.98776
# [300]	training's rmse: 0.813105	valid_1's rmse: 0.986941
# Early stopping, best iteration is:
# [266]	training's rmse: 0.827231	valid_1's rmse: 0.98651
# Partial score of fold 3 is: 0.5931030837868858
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.92026	valid_1's rmse: 0.993165
# [200]	training's rmse: 0.858326	valid_1's rmse: 0.984091
# [300]	training's rmse: 0.813854	valid_1's rmse: 0.984275
# Early stopping, best iteration is:
# [226]	training's rmse: 0.845743	valid_1's rmse: 0.983181
# Partial score of fold 4 is: 0.5829932882927122
# Our oof cohen kappa score is:  0.5891257799057975
# kappa:  0.5891257799057975
# |  30       |  0.5891   |  0.9449   |  0.07656  |  0.5241   |  0.03412  |  16.98    |  1.763    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.935181	valid_1's rmse: 0.98885
# [200]	training's rmse: 0.879015	valid_1's rmse: 0.978955
# [300]	training's rmse: 0.841526	valid_1's rmse: 0.980297
# Early stopping, best iteration is:
# [228]	training's rmse: 0.867617	valid_1's rmse: 0.978656
# Partial score of fold 0 is: 0.599958707784169
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.93246	valid_1's rmse: 0.995202
# [200]	training's rmse: 0.876477	valid_1's rmse: 0.990391
# [300]	training's rmse: 0.836935	valid_1's rmse: 0.991741
# Early stopping, best iteration is:
# [203]	training's rmse: 0.875195	valid_1's rmse: 0.990279
# Partial score of fold 1 is: 0.5854089028734453
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.934273	valid_1's rmse: 0.994154
# [200]	training's rmse: 0.878509	valid_1's rmse: 0.985729
# [300]	training's rmse: 0.840211	valid_1's rmse: 0.985594
# Early stopping, best iteration is:
# [236]	training's rmse: 0.863691	valid_1's rmse: 0.984824
# Partial score of fold 2 is: 0.5914926738282588
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.933544	valid_1's rmse: 0.999024
# [200]	training's rmse: 0.877159	valid_1's rmse: 0.990471
# [300]	training's rmse: 0.839099	valid_1's rmse: 0.989987
# Early stopping, best iteration is:
# [228]	training's rmse: 0.865753	valid_1's rmse: 0.989633
# Partial score of fold 3 is: 0.5914926738282588
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.93492	valid_1's rmse: 0.9959
# [200]	training's rmse: 0.879031	valid_1's rmse: 0.983837
# [300]	training's rmse: 0.840642	valid_1's rmse: 0.982342
# [400]	training's rmse: 0.809335	valid_1's rmse: 0.98271
# Early stopping, best iteration is:
# [368]	training's rmse: 0.819159	valid_1's rmse: 0.981673
# Partial score of fold 4 is: 0.5912278058881342
# Our oof cohen kappa score is:  0.5912374157059332
# kappa:  0.5912374157059332
# |  31       |  0.5912   |  0.7228   |  4.865    |  4.883    |  0.03496  |  16.77    |  9.608    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.951563	valid_1's rmse: 0.993777
# [200]	training's rmse: 0.897992	valid_1's rmse: 0.977187
# [300]	training's rmse: 0.862735	valid_1's rmse: 0.975374
# [400]	training's rmse: 0.833086	valid_1's rmse: 0.974288
# [500]	training's rmse: 0.807528	valid_1's rmse: 0.974675
# Early stopping, best iteration is:
# [412]	training's rmse: 0.829817	valid_1's rmse: 0.974081
# Partial score of fold 0 is: 0.6034038225538794
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.948802	valid_1's rmse: 1.0007
# [200]	training's rmse: 0.894779	valid_1's rmse: 0.990826
# [300]	training's rmse: 0.858855	valid_1's rmse: 0.990494
# Early stopping, best iteration is:
# [249]	training's rmse: 0.875828	valid_1's rmse: 0.990046
# Partial score of fold 1 is: 0.5863035750726826
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.949536	valid_1's rmse: 0.998952
# [200]	training's rmse: 0.895815	valid_1's rmse: 0.986411
# [300]	training's rmse: 0.86102	valid_1's rmse: 0.986289
# Early stopping, best iteration is:
# [237]	training's rmse: 0.881809	valid_1's rmse: 0.985499
# Partial score of fold 2 is: 0.5888086572305469
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.948252	valid_1's rmse: 1.00125
# [200]	training's rmse: 0.894944	valid_1's rmse: 0.990032
# [300]	training's rmse: 0.859521	valid_1's rmse: 0.987961
# [400]	training's rmse: 0.83094	valid_1's rmse: 0.98771
# Early stopping, best iteration is:
# [397]	training's rmse: 0.831783	valid_1's rmse: 0.987609
# Partial score of fold 3 is: 0.5948924281853605
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.95	valid_1's rmse: 1.00232
# [200]	training's rmse: 0.896245	valid_1's rmse: 0.986915
# [300]	training's rmse: 0.860232	valid_1's rmse: 0.984179
# [400]	training's rmse: 0.831189	valid_1's rmse: 0.983527
# Early stopping, best iteration is:
# [351]	training's rmse: 0.844817	valid_1's rmse: 0.983205
# Partial score of fold 4 is: 0.588228865808955
# Our oof cohen kappa score is:  0.5922753383873558
# kappa:  0.5922753383873558
# |  32       |  0.5923   |  0.8442   |  4.906    |  4.308    |  0.02722  |  15.48    |  3.183    |
# =================================================================================================

# %%
#cat_model = Catb_regr_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
lgb_model = Lgb_regr_Model(reduce_train, ajusted_test, features, categoricals=categoricals, ps=params)
xgb_model = Xgb_regr_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
# Out:
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:1243: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.926152	valid_1's rmse: 0.983976
# [200]	training's rmse: 0.867154	valid_1's rmse: 0.975482
# [300]	training's rmse: 0.825399	valid_1's rmse: 0.976083
# Early stopping, best iteration is:
# [204]	training's rmse: 0.86527	valid_1's rmse: 0.975257
# Partial score of fold 0 is: 0.598348523692066
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.922442	valid_1's rmse: 0.994322
# [200]	training's rmse: 0.864465	valid_1's rmse: 0.990493
# Early stopping, best iteration is:
# [177]	training's rmse: 0.875782	valid_1's rmse: 0.989817
# Partial score of fold 1 is: 0.5888086572305469
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.925131	valid_1's rmse: 0.992719
# [200]	training's rmse: 0.866169	valid_1's rmse: 0.987724
# [300]	training's rmse: 0.824703	valid_1's rmse: 0.987311
# Early stopping, best iteration is:
# [250]	training's rmse: 0.843764	valid_1's rmse: 0.986321
# Partial score of fold 2 is: 0.5877350505914622
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.923821	valid_1's rmse: 0.992726
# [200]	training's rmse: 0.866274	valid_1's rmse: 0.986724
# [300]	training's rmse: 0.824342	valid_1's rmse: 0.986639
# Early stopping, best iteration is:
# [262]	training's rmse: 0.839047	valid_1's rmse: 0.985781
# Partial score of fold 3 is: 0.5959660348244451
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.9248	valid_1's rmse: 0.992773
# [200]	training's rmse: 0.867757	valid_1's rmse: 0.984104
# [300]	training's rmse: 0.826583	valid_1's rmse: 0.983973
# [400]	training's rmse: 0.791307	valid_1's rmse: 0.984798
# Early stopping, best iteration is:
# [341]	training's rmse: 0.811223	valid_1's rmse: 0.983414
# Partial score of fold 4 is: 0.5894376933673902
# Our oof cohen kappa score is:  0.5917026913907089
# /opt/conda/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:1.85769	val-rmse:1.85882
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.01932	val-rmse:1.15606
# [200]	train-rmse:0.745315	val-rmse:1.01405
# [300]	train-rmse:0.631811	val-rmse:0.99035
# [400]	train-rmse:0.57533	val-rmse:0.988103
# Stopping. Best iteration:
# [386]	train-rmse:0.581321	val-rmse:0.987899
#
# Partial score of fold 0 is: 0.5872561443909114
# [0]	train-rmse:1.85768	val-rmse:1.85929
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.01375	val-rmse:1.17255
# [200]	train-rmse:0.736943	val-rmse:1.03104
# [300]	train-rmse:0.626955	val-rmse:1.00587
# [400]	train-rmse:0.573124	val-rmse:1.00191
# [500]	train-rmse:0.543882	val-rmse:1.00217
# Stopping. Best iteration:
# [462]	train-rmse:0.554671	val-rmse:1.00184
#
# Partial score of fold 1 is: 0.5687679999676319
# [0]	train-rmse:1.85765	val-rmse:1.85907
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.01687	val-rmse:1.15687
# [200]	train-rmse:0.74518	val-rmse:1.01441
# [300]	train-rmse:0.635536	val-rmse:0.992237
# [400]	train-rmse:0.579514	val-rmse:0.98971
# [500]	train-rmse:0.545293	val-rmse:0.989649
# Stopping. Best iteration:
# [429]	train-rmse:0.567322	val-rmse:0.989534
#
# Partial score of fold 2 is: 0.5850510339937505
# [0]	train-rmse:1.85766	val-rmse:1.85903
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.0127	val-rmse:1.16334
# [200]	train-rmse:0.737591	val-rmse:1.0242
# [300]	train-rmse:0.631071	val-rmse:1.0022
# [400]	train-rmse:0.577271	val-rmse:0.998026
# [500]	train-rmse:0.544997	val-rmse:0.997473
# [600]	train-rmse:0.522401	val-rmse:0.997885
# Stopping. Best iteration:
# [509]	train-rmse:0.542994	val-rmse:0.997362
#
# Partial score of fold 3 is: 0.57664111532092
# [0]	train-rmse:1.85756	val-rmse:1.85921
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 100 rounds.
# [100]	train-rmse:1.01832	val-rmse:1.16169
# [200]	train-rmse:0.743512	val-rmse:1.01955
# [300]	train-rmse:0.632663	val-rmse:0.996901
# [400]	train-rmse:0.578536	val-rmse:0.993958
# [500]	train-rmse:0.543544	val-rmse:0.993596
# Stopping. Best iteration:
# [478]	train-rmse:0.549605	val-rmse:0.993445
#
# Partial score of fold 4 is: 0.5668822756060172
# Our oof cohen kappa score is:  0.5777086304101484

# %%
#cnn_model = Cnn_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
nn_model = Nn_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:100: DeprecationWarning: The ``active_features_`` attribute was deprecated in version 0.20 and will be removed 0.22.
#   warnings.warn(msg, category=DeprecationWarning)
# (17690, 369)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200)               74000
# _________________________________________________________________
# layer_normalization (LayerNo (None, 200)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               20100
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 100)               200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 50)                100
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 25)                1275
# _________________________________________________________________
# layer_normalization_3 (Layer (None, 25)                50
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 101,201
# Trainable params: 101,201
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14151 samples, validate on 3539 samples
# Epoch 1/100
# 13984/14151 [============================>.] - ETA: 0s - loss: 2.0545
# Epoch 00001: val_loss improved from inf to 1.19752, saving model to nn_model.w8
# 14151/14151 [==============================] - 4s 264us/sample - loss: 2.0480 - val_loss: 1.1975
# Epoch 2/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 1.4387
# Epoch 00002: val_loss improved from 1.19752 to 1.12418, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 187us/sample - loss: 1.4366 - val_loss: 1.1242
# Epoch 3/100
# 14048/14151 [============================>.] - ETA: 0s - loss: 1.3130
# Epoch 00003: val_loss improved from 1.12418 to 1.09536, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 184us/sample - loss: 1.3134 - val_loss: 1.0954
# Epoch 4/100
# 14144/14151 [============================>.] - ETA: 0s - loss: 1.2451
# Epoch 00004: val_loss improved from 1.09536 to 1.07395, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 191us/sample - loss: 1.2449 - val_loss: 1.0739
# Epoch 5/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 1.1930
# Epoch 00005: val_loss improved from 1.07395 to 1.06599, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 202us/sample - loss: 1.1927 - val_loss: 1.0660
# Epoch 6/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 1.2016
# Epoch 00006: val_loss improved from 1.06599 to 1.04476, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 200us/sample - loss: 1.1991 - val_loss: 1.0448
# Epoch 7/100
# 14144/14151 [============================>.] - ETA: 0s - loss: 1.1639
# Epoch 00007: val_loss did not improve from 1.04476
# 14151/14151 [==============================] - 3s 197us/sample - loss: 1.1641 - val_loss: 1.0574
# Epoch 8/100
# 14080/14151 [============================>.] - ETA: 0s - loss: 1.1374
# Epoch 00008: val_loss improved from 1.04476 to 1.03037, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 185us/sample - loss: 1.1373 - val_loss: 1.0304
# Epoch 9/100
# 13920/14151 [============================>.] - ETA: 0s - loss: 1.1223
# Epoch 00009: val_loss did not improve from 1.03037
# 14151/14151 [==============================] - 3s 190us/sample - loss: 1.1221 - val_loss: 1.0430
# Epoch 10/100
# 13856/14151 [============================>.] - ETA: 0s - loss: 1.1162
# Epoch 00010: val_loss improved from 1.03037 to 1.02712, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 191us/sample - loss: 1.1157 - val_loss: 1.0271
# Epoch 11/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 1.0899
# Epoch 00011: val_loss improved from 1.02712 to 1.00455, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 194us/sample - loss: 1.0898 - val_loss: 1.0045
# Epoch 12/100
# 14144/14151 [============================>.] - ETA: 0s - loss: 1.0726
# Epoch 00012: val_loss improved from 1.00455 to 0.99784, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 202us/sample - loss: 1.0722 - val_loss: 0.9978
# Epoch 13/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 1.0795
# Epoch 00013: val_loss did not improve from 0.99784
# 14151/14151 [==============================] - 3s 195us/sample - loss: 1.0794 - val_loss: 1.0140
# Epoch 14/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 1.0607
# Epoch 00014: val_loss did not improve from 0.99784
# 14151/14151 [==============================] - 3s 187us/sample - loss: 1.0608 - val_loss: 1.0150
# Epoch 15/100
# 13984/14151 [============================>.] - ETA: 0s - loss: 1.0527
# Epoch 00015: val_loss did not improve from 0.99784
# 14151/14151 [==============================] - 3s 195us/sample - loss: 1.0509 - val_loss: 1.0007
# Epoch 16/100
# 13984/14151 [============================>.] - ETA: 0s - loss: 1.0458
# Epoch 00016: val_loss improved from 0.99784 to 0.99236, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 202us/sample - loss: 1.0467 - val_loss: 0.9924
# Epoch 17/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 1.0388
# Epoch 00017: val_loss improved from 0.99236 to 0.98799, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 204us/sample - loss: 1.0394 - val_loss: 0.9880
# Epoch 18/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 1.0225
# Epoch 00018: val_loss improved from 0.98799 to 0.98417, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 206us/sample - loss: 1.0203 - val_loss: 0.9842
# Epoch 19/100
# 13920/14151 [============================>.] - ETA: 0s - loss: 1.0235
# Epoch 00019: val_loss did not improve from 0.98417
# 14151/14151 [==============================] - 3s 199us/sample - loss: 1.0251 - val_loss: 0.9916
# Epoch 20/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 1.0173
# Epoch 00020: val_loss improved from 0.98417 to 0.98071, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 195us/sample - loss: 1.0172 - val_loss: 0.9807
# Epoch 21/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 0.9995
# Epoch 00021: val_loss improved from 0.98071 to 0.97978, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 199us/sample - loss: 0.9988 - val_loss: 0.9798
# Epoch 22/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 0.9987
# Epoch 00022: val_loss did not improve from 0.97978
# 14151/14151 [==============================] - 3s 200us/sample - loss: 0.9951 - val_loss: 0.9978
# Epoch 23/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.9838
# Epoch 00023: val_loss improved from 0.97978 to 0.97831, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 201us/sample - loss: 0.9849 - val_loss: 0.9783
# Epoch 24/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 0.9796
# Epoch 00024: val_loss did not improve from 0.97831
# 14151/14151 [==============================] - 3s 201us/sample - loss: 0.9797 - val_loss: 0.9855
# Epoch 25/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 0.9697
# Epoch 00025: val_loss did not improve from 0.97831
# 14151/14151 [==============================] - 3s 195us/sample - loss: 0.9682 - val_loss: 0.9817
# Epoch 26/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 0.9685
# Epoch 00026: val_loss improved from 0.97831 to 0.97443, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 187us/sample - loss: 0.9674 - val_loss: 0.9744
# Epoch 27/100
# 13984/14151 [============================>.] - ETA: 0s - loss: 0.9630
# Epoch 00027: val_loss did not improve from 0.97443
# 14151/14151 [==============================] - 3s 189us/sample - loss: 0.9617 - val_loss: 0.9748
# Epoch 28/100
# 13984/14151 [============================>.] - ETA: 0s - loss: 0.9431
# Epoch 00028: val_loss did not improve from 0.97443
# 14151/14151 [==============================] - 3s 192us/sample - loss: 0.9430 - val_loss: 0.9871
# Epoch 29/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.9379
# Epoch 00029: val_loss improved from 0.97443 to 0.97442, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 196us/sample - loss: 0.9395 - val_loss: 0.9744
# Epoch 30/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 0.9358
# Epoch 00030: val_loss did not improve from 0.97442
# 14151/14151 [==============================] - 3s 196us/sample - loss: 0.9355 - val_loss: 1.0103
# Epoch 31/100
# 13856/14151 [============================>.] - ETA: 0s - loss: 0.9268
# Epoch 00031: val_loss did not improve from 0.97442
# 14151/14151 [==============================] - 3s 193us/sample - loss: 0.9276 - val_loss: 0.9772
# Epoch 32/100
# 14048/14151 [============================>.] - ETA: 0s - loss: 0.9151
# Epoch 00032: val_loss did not improve from 0.97442
# 14151/14151 [==============================] - 3s 184us/sample - loss: 0.9149 - val_loss: 0.9960
# Epoch 33/100
# 13856/14151 [============================>.] - ETA: 0s - loss: 0.9206
# Epoch 00033: val_loss did not improve from 0.97442
# 14151/14151 [==============================] - 3s 185us/sample - loss: 0.9182 - val_loss: 0.9870
# Epoch 34/100
# 14144/14151 [============================>.] - ETA: 0s - loss: 0.9104
# Epoch 00034: val_loss did not improve from 0.97442
# 14151/14151 [==============================] - 3s 188us/sample - loss: 0.9107 - val_loss: 0.9792
# Epoch 35/100
# 14080/14151 [============================>.] - ETA: 0s - loss: 0.9056
# Epoch 00035: val_loss improved from 0.97442 to 0.97359, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 193us/sample - loss: 0.9059 - val_loss: 0.9736
# Epoch 36/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 0.8839
# Epoch 00036: val_loss did not improve from 0.97359
# 14151/14151 [==============================] - 3s 196us/sample - loss: 0.8855 - val_loss: 0.9832
# Epoch 37/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 0.8868
# Epoch 00037: val_loss did not improve from 0.97359
# 14151/14151 [==============================] - 3s 196us/sample - loss: 0.8862 - val_loss: 0.9842
# Epoch 38/100
# 13920/14151 [============================>.] - ETA: 0s - loss: 0.8742
# Epoch 00038: val_loss did not improve from 0.97359
# 14151/14151 [==============================] - 3s 192us/sample - loss: 0.8743 - val_loss: 0.9961
# Epoch 39/100
# 13920/14151 [============================>.] - ETA: 0s - loss: 0.8775
# Epoch 00039: val_loss did not improve from 0.97359
# 14151/14151 [==============================] - 3s 191us/sample - loss: 0.8774 - val_loss: 1.0031
# Epoch 40/100
# 13984/14151 [============================>.] - ETA: 0s - loss: 0.8789
# Epoch 00040: val_loss did not improve from 0.97359
# 14151/14151 [==============================] - 3s 196us/sample - loss: 0.8798 - val_loss: 0.9842
# Epoch 41/100
# 13920/14151 [============================>.] - ETA: 0s - loss: 0.8648
# Epoch 00041: val_loss did not improve from 0.97359
# 14151/14151 [==============================] - 3s 200us/sample - loss: 0.8636 - val_loss: 0.9951
# Epoch 42/100
# 14144/14151 [============================>.] - ETA: 0s - loss: 0.8515
# Epoch 00042: val_loss did not improve from 0.97359
# 14151/14151 [==============================] - 3s 200us/sample - loss: 0.8521 - val_loss: 0.9942
# Epoch 43/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.8537
# Epoch 00043: val_loss did not improve from 0.97359
# 14151/14151 [==============================] - 3s 195us/sample - loss: 0.8534 - val_loss: 0.9863
# Epoch 44/100
# 13920/14151 [============================>.] - ETA: 0s - loss: 0.8508
# Epoch 00044: val_loss did not improve from 0.97359
# 14151/14151 [==============================] - 3s 194us/sample - loss: 0.8515 - val_loss: 0.9764
# Epoch 45/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 0.8439
# Epoch 00045: val_loss did not improve from 0.97359
# 14151/14151 [==============================] - 3s 189us/sample - loss: 0.8447 - val_loss: 0.9886
# Epoch 46/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.8482
# Epoch 00046: val_loss did not improve from 0.97359
# 14151/14151 [==============================] - 3s 185us/sample - loss: 0.8483 - val_loss: 0.9868
# Epoch 47/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 0.8301
# Epoch 00047: val_loss did not improve from 0.97359
# 14151/14151 [==============================] - 3s 216us/sample - loss: 0.8310 - val_loss: 1.0027
# Epoch 48/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 0.8278
# Epoch 00048: val_loss improved from 0.97359 to 0.96875, saving model to nn_model.w8
# 14151/14151 [==============================] - 3s 217us/sample - loss: 0.8287 - val_loss: 0.9688
# Epoch 49/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 0.8295
# Epoch 00049: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 194us/sample - loss: 0.8268 - val_loss: 1.0048
# Epoch 50/100
# 14080/14151 [============================>.] - ETA: 0s - loss: 0.8125
# Epoch 00050: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 191us/sample - loss: 0.8122 - val_loss: 0.9886
# Epoch 51/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 0.8108
# Epoch 00051: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 186us/sample - loss: 0.8118 - val_loss: 0.9860
# Epoch 52/100
# 13984/14151 [============================>.] - ETA: 0s - loss: 0.8083
# Epoch 00052: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 183us/sample - loss: 0.8099 - val_loss: 0.9945
# Epoch 53/100
# 14144/14151 [============================>.] - ETA: 0s - loss: 0.7921
# Epoch 00053: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 191us/sample - loss: 0.7917 - val_loss: 1.0037
# Epoch 54/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 0.7888
# Epoch 00054: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 196us/sample - loss: 0.7895 - val_loss: 0.9955
# Epoch 55/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 0.7930
# Epoch 00055: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 198us/sample - loss: 0.7926 - val_loss: 0.9851
# Epoch 56/100
# 13984/14151 [============================>.] - ETA: 0s - loss: 0.7857
# Epoch 00056: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 186us/sample - loss: 0.7857 - val_loss: 1.0165
# Epoch 57/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.7859
# Epoch 00057: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 185us/sample - loss: 0.7844 - val_loss: 1.0117
# Epoch 58/100
# 13888/14151 [============================>.] - ETA: 0s - loss: 0.7822
# Epoch 00058: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 186us/sample - loss: 0.7837 - val_loss: 1.0125
# Epoch 59/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 0.7699
# Epoch 00059: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 198us/sample - loss: 0.7682 - val_loss: 1.0477
# Epoch 60/100
# 14048/14151 [============================>.] - ETA: 0s - loss: 0.7715
# Epoch 00060: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 201us/sample - loss: 0.7711 - val_loss: 1.0114
# Epoch 61/100
# 14048/14151 [============================>.] - ETA: 0s - loss: 0.7624
# Epoch 00061: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 194us/sample - loss: 0.7631 - val_loss: 1.0045
# Epoch 62/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.7619
# Epoch 00062: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 189us/sample - loss: 0.7640 - val_loss: 1.0024
# Epoch 63/100
# 13952/14151 [============================>.] - ETA: 0s - loss: 0.7491
# Epoch 00063: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 186us/sample - loss: 0.7484 - val_loss: 1.0221
# Epoch 64/100
# 13920/14151 [============================>.] - ETA: 0s - loss: 0.7548
# Epoch 00064: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 187us/sample - loss: 0.7552 - val_loss: 1.0237
# Epoch 65/100
# 13984/14151 [============================>.] - ETA: 0s - loss: 0.7513
# Epoch 00065: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 193us/sample - loss: 0.7505 - val_loss: 1.0276
# Epoch 66/100
# 14016/14151 [============================>.] - ETA: 0s - loss: 0.7450
# Epoch 00066: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 195us/sample - loss: 0.7466 - val_loss: 1.0217
# Epoch 67/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 0.7541
# Epoch 00067: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 208us/sample - loss: 0.7541 - val_loss: 1.0197
# Epoch 68/100
# 14112/14151 [============================>.] - ETA: 0s - loss: 0.7472
# Epoch 00068: val_loss did not improve from 0.96875
# 14151/14151 [==============================] - 3s 204us/sample - loss: 0.7469 - val_loss: 1.0135
# Partial score of fold 0 is: 0.5942336087900248
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 200)               74000
# _________________________________________________________________
# layer_normalization_4 (Layer (None, 200)               400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               20100
# _________________________________________________________________
# layer_normalization_5 (Layer (None, 100)               200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                5050
# _________________________________________________________________
# layer_normalization_6 (Layer (None, 50)                100
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 25)                1275
# _________________________________________________________________
# layer_normalization_7 (Layer (None, 25)                50
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 25)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 101,201
# Trainable params: 101,201
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14152 samples, validate on 3538 samples
# Epoch 1/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 1.8283
# Epoch 00001: val_loss improved from inf to 1.14406, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 247us/sample - loss: 1.8278 - val_loss: 1.1441
# Epoch 2/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 1.3926
# Epoch 00002: val_loss improved from 1.14406 to 1.08683, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 196us/sample - loss: 1.3929 - val_loss: 1.0868
# Epoch 3/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 1.2987
# Epoch 00003: val_loss improved from 1.08683 to 1.05703, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 195us/sample - loss: 1.2993 - val_loss: 1.0570
# Epoch 4/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 1.2271
# Epoch 00004: val_loss improved from 1.05703 to 1.04530, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 185us/sample - loss: 1.2268 - val_loss: 1.0453
# Epoch 5/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.1966
# Epoch 00005: val_loss improved from 1.04530 to 1.04311, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 190us/sample - loss: 1.1954 - val_loss: 1.0431
# Epoch 6/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 1.1572
# Epoch 00006: val_loss improved from 1.04311 to 1.03885, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 185us/sample - loss: 1.1598 - val_loss: 1.0389
# Epoch 7/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 1.1599
# Epoch 00007: val_loss improved from 1.03885 to 1.02596, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 187us/sample - loss: 1.1602 - val_loss: 1.0260
# Epoch 8/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 1.1241
# Epoch 00008: val_loss did not improve from 1.02596
# 14152/14152 [==============================] - 3s 192us/sample - loss: 1.1240 - val_loss: 1.0455
# Epoch 9/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 1.1103
# Epoch 00009: val_loss improved from 1.02596 to 1.02120, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 199us/sample - loss: 1.1125 - val_loss: 1.0212
# Epoch 10/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 1.0895
# Epoch 00010: val_loss did not improve from 1.02120
# 14152/14152 [==============================] - 3s 193us/sample - loss: 1.0880 - val_loss: 1.0233
# Epoch 11/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 1.0785
# Epoch 00011: val_loss improved from 1.02120 to 1.01789, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 195us/sample - loss: 1.0786 - val_loss: 1.0179
# Epoch 12/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 1.0745
# Epoch 00012: val_loss did not improve from 1.01789
# 14152/14152 [==============================] - 3s 200us/sample - loss: 1.0741 - val_loss: 1.0298
# Epoch 13/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 1.0499
# Epoch 00013: val_loss improved from 1.01789 to 1.01212, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 188us/sample - loss: 1.0498 - val_loss: 1.0121
# Epoch 14/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 1.0472
# Epoch 00014: val_loss did not improve from 1.01212
# 14152/14152 [==============================] - 3s 199us/sample - loss: 1.0463 - val_loss: 1.0148
# Epoch 15/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.0398
# Epoch 00015: val_loss improved from 1.01212 to 0.99818, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 199us/sample - loss: 1.0399 - val_loss: 0.9982
# Epoch 16/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 1.0134
# Epoch 00016: val_loss did not improve from 0.99818
# 14152/14152 [==============================] - 3s 189us/sample - loss: 1.0138 - val_loss: 1.0219
# Epoch 17/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.0113
# Epoch 00017: val_loss did not improve from 0.99818
# 14152/14152 [==============================] - 3s 189us/sample - loss: 1.0103 - val_loss: 0.9989
# Epoch 18/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 1.0050
# Epoch 00018: val_loss did not improve from 0.99818
# 14152/14152 [==============================] - 3s 186us/sample - loss: 1.0038 - val_loss: 1.0132
# Epoch 19/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.9926
# Epoch 00019: val_loss did not improve from 0.99818
# 14152/14152 [==============================] - 3s 182us/sample - loss: 0.9920 - val_loss: 1.0076
# Epoch 20/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9835
# Epoch 00020: val_loss did not improve from 0.99818
# 14152/14152 [==============================] - 3s 190us/sample - loss: 0.9818 - val_loss: 1.0200
# Epoch 21/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.9753
# Epoch 00021: val_loss did not improve from 0.99818
# 14152/14152 [==============================] - 3s 191us/sample - loss: 0.9756 - val_loss: 1.0182
# Epoch 22/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.9687
# Epoch 00022: val_loss did not improve from 0.99818
# 14152/14152 [==============================] - 3s 191us/sample - loss: 0.9669 - val_loss: 1.0200
# Epoch 23/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.9610
# Epoch 00023: val_loss improved from 0.99818 to 0.99321, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 181us/sample - loss: 0.9617 - val_loss: 0.9932
# Epoch 24/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.9597
# Epoch 00024: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 181us/sample - loss: 0.9592 - val_loss: 1.0192
# Epoch 25/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.9398
# Epoch 00025: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 186us/sample - loss: 0.9380 - val_loss: 1.0079
# Epoch 26/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.9317
# Epoch 00026: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 189us/sample - loss: 0.9318 - val_loss: 1.0255
# Epoch 27/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.9203
# Epoch 00027: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 193us/sample - loss: 0.9203 - val_loss: 1.0459
# Epoch 28/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.9182
# Epoch 00028: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 191us/sample - loss: 0.9206 - val_loss: 1.0155
# Epoch 29/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9087
# Epoch 00029: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 188us/sample - loss: 0.9131 - val_loss: 1.0246
# Epoch 30/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.9017
# Epoch 00030: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 187us/sample - loss: 0.9017 - val_loss: 1.0226
# Epoch 31/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.8842
# Epoch 00031: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 184us/sample - loss: 0.8852 - val_loss: 1.0256
# Epoch 32/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.8971
# Epoch 00032: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 196us/sample - loss: 0.8966 - val_loss: 1.0460
# Epoch 33/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.8897
# Epoch 00033: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 201us/sample - loss: 0.8898 - val_loss: 1.0176
# Epoch 34/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.8755
# Epoch 00034: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 205us/sample - loss: 0.8757 - val_loss: 1.0171
# Epoch 35/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 0.8707
# Epoch 00035: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 198us/sample - loss: 0.8706 - val_loss: 1.0495
# Epoch 36/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.8645
# Epoch 00036: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 196us/sample - loss: 0.8622 - val_loss: 1.0415
# Epoch 37/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.8489
# Epoch 00037: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 190us/sample - loss: 0.8504 - val_loss: 1.0201
# Epoch 38/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.8536
# Epoch 00038: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 194us/sample - loss: 0.8535 - val_loss: 1.0391
# Epoch 39/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.8481
# Epoch 00039: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 195us/sample - loss: 0.8454 - val_loss: 1.0553
# Epoch 40/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.8481
# Epoch 00040: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 192us/sample - loss: 0.8482 - val_loss: 1.0524
# Epoch 41/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.8395
# Epoch 00041: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 188us/sample - loss: 0.8389 - val_loss: 1.0293
# Epoch 42/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.8252
# Epoch 00042: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 183us/sample - loss: 0.8259 - val_loss: 1.0500
# Epoch 43/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.8267
# Epoch 00043: val_loss did not improve from 0.99321
# 14152/14152 [==============================] - 3s 184us/sample - loss: 0.8256 - val_loss: 1.0618
# Partial score of fold 1 is: 0.5850510339937505
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 200)               74000
# _________________________________________________________________
# layer_normalization_8 (Layer (None, 200)               400
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 100)               20100
# _________________________________________________________________
# layer_normalization_9 (Layer (None, 100)               200
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 50)                5050
# _________________________________________________________________
# layer_normalization_10 (Laye (None, 50)                100
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 25)                1275
# _________________________________________________________________
# layer_normalization_11 (Laye (None, 25)                50
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 101,201
# Trainable params: 101,201
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14152 samples, validate on 3538 samples
# Epoch 1/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 1.8966
# Epoch 00001: val_loss improved from inf to 1.16514, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 243us/sample - loss: 1.8875 - val_loss: 1.1651
# Epoch 2/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.3806
# Epoch 00002: val_loss improved from 1.16514 to 1.09988, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 198us/sample - loss: 1.3800 - val_loss: 1.0999
# Epoch 3/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 1.2790
# Epoch 00003: val_loss improved from 1.09988 to 1.09144, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 192us/sample - loss: 1.2774 - val_loss: 1.0914
# Epoch 4/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.2220
# Epoch 00004: val_loss improved from 1.09144 to 1.07748, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 191us/sample - loss: 1.2220 - val_loss: 1.0775
# Epoch 5/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 1.1875
# Epoch 00005: val_loss improved from 1.07748 to 1.05821, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 187us/sample - loss: 1.1881 - val_loss: 1.0582
# Epoch 6/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.1582
# Epoch 00006: val_loss did not improve from 1.05821
# 14152/14152 [==============================] - 3s 201us/sample - loss: 1.1594 - val_loss: 1.0881
# Epoch 7/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.1408
# Epoch 00007: val_loss did not improve from 1.05821
# 14152/14152 [==============================] - 3s 198us/sample - loss: 1.1420 - val_loss: 1.0622
# Epoch 8/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.1222
# Epoch 00008: val_loss improved from 1.05821 to 1.05327, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 198us/sample - loss: 1.1223 - val_loss: 1.0533
# Epoch 9/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 1.1088
# Epoch 00009: val_loss improved from 1.05327 to 1.04132, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 189us/sample - loss: 1.1100 - val_loss: 1.0413
# Epoch 10/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 1.0975
# Epoch 00010: val_loss did not improve from 1.04132
# 14152/14152 [==============================] - 3s 186us/sample - loss: 1.0988 - val_loss: 1.0435
# Epoch 11/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 1.0886
# Epoch 00011: val_loss improved from 1.04132 to 1.02697, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 197us/sample - loss: 1.0880 - val_loss: 1.0270
# Epoch 12/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.0644
# Epoch 00012: val_loss did not improve from 1.02697
# 14152/14152 [==============================] - 3s 212us/sample - loss: 1.0641 - val_loss: 1.0302
# Epoch 13/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 1.0610
# Epoch 00013: val_loss did not improve from 1.02697
# 14152/14152 [==============================] - 3s 199us/sample - loss: 1.0592 - val_loss: 1.0386
# Epoch 14/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 1.0472
# Epoch 00014: val_loss improved from 1.02697 to 1.02286, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 206us/sample - loss: 1.0475 - val_loss: 1.0229
# Epoch 15/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 1.0366
# Epoch 00015: val_loss did not improve from 1.02286
# 14152/14152 [==============================] - 3s 188us/sample - loss: 1.0370 - val_loss: 1.0814
# Epoch 16/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 1.0235
# Epoch 00016: val_loss did not improve from 1.02286
# 14152/14152 [==============================] - 3s 192us/sample - loss: 1.0243 - val_loss: 1.0498
# Epoch 17/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 1.0177
# Epoch 00017: val_loss improved from 1.02286 to 1.01207, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 197us/sample - loss: 1.0166 - val_loss: 1.0121
# Epoch 18/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 1.0069
# Epoch 00018: val_loss did not improve from 1.01207
# 14152/14152 [==============================] - 3s 206us/sample - loss: 1.0069 - val_loss: 1.0177
# Epoch 19/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.9928
# Epoch 00019: val_loss improved from 1.01207 to 1.00548, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 205us/sample - loss: 0.9934 - val_loss: 1.0055
# Epoch 20/100
# 13856/14152 [============================>.] - ETA: 0s - loss: 0.9814
# Epoch 00020: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 195us/sample - loss: 0.9836 - val_loss: 1.0252
# Epoch 21/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.9755
# Epoch 00021: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 194us/sample - loss: 0.9758 - val_loss: 1.0113
# Epoch 22/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.9631
# Epoch 00022: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 190us/sample - loss: 0.9634 - val_loss: 1.0090
# Epoch 23/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.9640
# Epoch 00023: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 197us/sample - loss: 0.9639 - val_loss: 1.0360
# Epoch 24/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.9537
# Epoch 00024: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 203us/sample - loss: 0.9546 - val_loss: 1.0106
# Epoch 25/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.9480
# Epoch 00025: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 209us/sample - loss: 0.9438 - val_loss: 1.0402
# Epoch 26/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.9446
# Epoch 00026: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 196us/sample - loss: 0.9443 - val_loss: 1.0103
# Epoch 27/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.9314
# Epoch 00027: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 201us/sample - loss: 0.9317 - val_loss: 1.0122
# Epoch 28/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.9185
# Epoch 00028: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 194us/sample - loss: 0.9184 - val_loss: 1.0082
# Epoch 29/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.9124
# Epoch 00029: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 194us/sample - loss: 0.9122 - val_loss: 1.0237
# Epoch 30/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.9076
# Epoch 00030: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 199us/sample - loss: 0.9083 - val_loss: 1.0064
# Epoch 31/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.9044
# Epoch 00031: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 199us/sample - loss: 0.9028 - val_loss: 1.0172
# Epoch 32/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.8931
# Epoch 00032: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 211us/sample - loss: 0.8932 - val_loss: 1.0236
# Epoch 33/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.8854
# Epoch 00033: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 195us/sample - loss: 0.8848 - val_loss: 1.0265
# Epoch 34/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.8833
# Epoch 00034: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 191us/sample - loss: 0.8831 - val_loss: 1.0284
# Epoch 35/100
# 14048/14152 [============================>.] - ETA: 0s - loss: 0.8831
# Epoch 00035: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 197us/sample - loss: 0.8839 - val_loss: 1.0207
# Epoch 36/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.8627
# Epoch 00036: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 201us/sample - loss: 0.8636 - val_loss: 1.0136
# Epoch 37/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.8580
# Epoch 00037: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 200us/sample - loss: 0.8595 - val_loss: 1.0185
# Epoch 38/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 0.8555
# Epoch 00038: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 187us/sample - loss: 0.8544 - val_loss: 1.0389
# Epoch 39/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 0.8450
# Epoch 00039: val_loss did not improve from 1.00548
# 14152/14152 [==============================] - 3s 194us/sample - loss: 0.8449 - val_loss: 1.0145
# Partial score of fold 2 is: 0.5811144763171063
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 200)               74000
# _________________________________________________________________
# layer_normalization_12 (Laye (None, 200)               400
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 100)               20100
# _________________________________________________________________
# layer_normalization_13 (Laye (None, 100)               200
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 50)                5050
# _________________________________________________________________
# layer_normalization_14 (Laye (None, 50)                100
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 25)                1275
# _________________________________________________________________
# layer_normalization_15 (Laye (None, 25)                50
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 101,201
# Trainable params: 101,201
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14152 samples, validate on 3538 samples
# Epoch 1/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 2.0188
# Epoch 00001: val_loss improved from inf to 1.18865, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 243us/sample - loss: 2.0085 - val_loss: 1.1886
# Epoch 2/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 1.4496
# Epoch 00002: val_loss improved from 1.18865 to 1.13459, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 202us/sample - loss: 1.4495 - val_loss: 1.1346
# Epoch 3/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.3139
# Epoch 00003: val_loss improved from 1.13459 to 1.09000, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 203us/sample - loss: 1.3139 - val_loss: 1.0900
# Epoch 4/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.2303
# Epoch 00004: val_loss improved from 1.09000 to 1.07202, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 195us/sample - loss: 1.2291 - val_loss: 1.0720
# Epoch 5/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 1.2127
# Epoch 00005: val_loss did not improve from 1.07202
# 14152/14152 [==============================] - 3s 211us/sample - loss: 1.2102 - val_loss: 1.0760
# Epoch 6/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 1.1776
# Epoch 00006: val_loss improved from 1.07202 to 1.05938, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 213us/sample - loss: 1.1785 - val_loss: 1.0594
# Epoch 7/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 1.1631
# Epoch 00007: val_loss improved from 1.05938 to 1.05394, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 201us/sample - loss: 1.1618 - val_loss: 1.0539
# Epoch 8/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 1.1342
# Epoch 00008: val_loss did not improve from 1.05394
# 14152/14152 [==============================] - 3s 205us/sample - loss: 1.1352 - val_loss: 1.0604
# Epoch 9/100
# 13984/14152 [============================>.] - ETA: 0s - loss: 1.1262
# Epoch 00009: val_loss improved from 1.05394 to 1.04413, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 198us/sample - loss: 1.1264 - val_loss: 1.0441
# Epoch 10/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 1.1135
# Epoch 00010: val_loss improved from 1.04413 to 1.03149, saving model to nn_model.w8
# ...
# Epoch 29/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.9276
# Epoch 00029: val_loss did not improve from 1.00642
# 14152/14152 [==============================] - 3s 206us/sample - loss: 0.9302 - val_loss: 1.0298
# Epoch 30/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.9379
# Epoch 00030: val_loss did not improve from 1.00642
# 14152/14152 [==============================] - 3s 194us/sample - loss: 0.9395 - val_loss: 1.0339
# Epoch 31/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.9260
# Epoch 00031: val_loss improved from 1.00642 to 1.00592, saving model to nn_model.w8
# 14152/14152 [==============================] - 3s 203us/sample - loss: 0.9252 - val_loss: 1.0059
# Epoch 32/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.9157
# Epoch 00032: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 201us/sample - loss: 0.9141 - val_loss: 1.0092
# Epoch 33/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.9046
# Epoch 00033: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 197us/sample - loss: 0.9025 - val_loss: 1.0192
# Epoch 34/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.8941
# Epoch 00034: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 199us/sample - loss: 0.8937 - val_loss: 1.0240
# Epoch 35/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.8912
# Epoch 00035: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 203us/sample - loss: 0.8925 - val_loss: 1.0256
# Epoch 36/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.8847
# Epoch 00036: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 198us/sample - loss: 0.8847 - val_loss: 1.0065
# Epoch 37/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.8715
# Epoch 00037: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 205us/sample - loss: 0.8707 - val_loss: 1.0314
# Epoch 38/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.8762
# Epoch 00038: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 206us/sample - loss: 0.8775 - val_loss: 1.0149
# Epoch 39/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.8650
# Epoch 00039: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 197us/sample - loss: 0.8654 - val_loss: 1.0417
# Epoch 40/100
# 14144/14152 [============================>.] - ETA: 0s - loss: 0.8607
# Epoch 00040: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 193us/sample - loss: 0.8606 - val_loss: 1.0256
# Epoch 41/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.8579
# Epoch 00041: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 195us/sample - loss: 0.8574 - val_loss: 1.0486
# Epoch 42/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.8458
# Epoch 00042: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 200us/sample - loss: 0.8458 - val_loss: 1.0239
# Epoch 43/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.8337
# Epoch 00043: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 203us/sample - loss: 0.8337 - val_loss: 1.0242
# Epoch 44/100
# 14112/14152 [============================>.] - ETA: 0s - loss: 0.8334
# Epoch 00044: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 203us/sample - loss: 0.8337 - val_loss: 1.0217
# Epoch 45/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.8385
# Epoch 00045: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 191us/sample - loss: 0.8416 - val_loss: 1.0275
# Epoch 46/100
# 14080/14152 [============================>.] - ETA: 0s - loss: 0.8252
# Epoch 00046: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 195us/sample - loss: 0.8241 - val_loss: 1.0214
# Epoch 47/100
# 13920/14152 [============================>.] - ETA: 0s - loss: 0.8313
# Epoch 00047: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 190us/sample - loss: 0.8303 - val_loss: 1.0441
# Epoch 48/100
# 14016/14152 [============================>.] - ETA: 0s - loss: 0.8309
# Epoch 00048: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 193us/sample - loss: 0.8303 - val_loss: 1.0280
# Epoch 49/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.8105
# Epoch 00049: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 201us/sample - loss: 0.8108 - val_loss: 1.0632
# Epoch 50/100
# 13952/14152 [============================>.] - ETA: 0s - loss: 0.8156
# Epoch 00050: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 199us/sample - loss: 0.8176 - val_loss: 1.0437
# Epoch 51/100
# 13888/14152 [============================>.] - ETA: 0s - loss: 0.8073
# Epoch 00051: val_loss did not improve from 1.00592
# 14152/14152 [==============================] - 3s 189us/sample - loss: 0.8069 - val_loss: 1.0486
# Partial score of fold 3 is: 0.5812934107569538
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 200)               74000
# _________________________________________________________________
# layer_normalization_16 (Laye (None, 200)               400
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 100)               20100
# _________________________________________________________________
# layer_normalization_17 (Laye (None, 100)               200
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 50)                5050
# _________________________________________________________________
# layer_normalization_18 (Laye (None, 50)                100
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 25)                1275
# _________________________________________________________________
# layer_normalization_19 (Laye (None, 25)                50
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 101,201
# Trainable params: 101,201
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14153 samples, validate on 3537 samples
# Epoch 1/100
# 13920/14153 [============================>.] - ETA: 0s - loss: 2.0524
# Epoch 00001: val_loss improved from inf to 1.18773, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 242us/sample - loss: 2.0447 - val_loss: 1.1877
# Epoch 2/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 1.4927
# Epoch 00002: val_loss improved from 1.18773 to 1.11719, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 198us/sample - loss: 1.4930 - val_loss: 1.1172
# Epoch 3/100
# 14080/14153 [============================>.] - ETA: 0s - loss: 1.3314
# Epoch 00003: val_loss improved from 1.11719 to 1.09519, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 205us/sample - loss: 1.3284 - val_loss: 1.0952
# Epoch 4/100
# 13920/14153 [============================>.] - ETA: 0s - loss: 1.2609
# Epoch 00004: val_loss improved from 1.09519 to 1.08961, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 207us/sample - loss: 1.2584 - val_loss: 1.0896
# Epoch 5/100
# 14048/14153 [============================>.] - ETA: 0s - loss: 1.2154
# Epoch 00005: val_loss improved from 1.08961 to 1.06239, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 200us/sample - loss: 1.2169 - val_loss: 1.0624
# Epoch 6/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 1.1812
# Epoch 00006: val_loss did not improve from 1.06239
# 14153/14153 [==============================] - 3s 194us/sample - loss: 1.1824 - val_loss: 1.0821
# Epoch 7/100
# 13920/14153 [============================>.] - ETA: 0s - loss: 1.1571
# Epoch 00007: val_loss improved from 1.06239 to 1.05187, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 197us/sample - loss: 1.1581 - val_loss: 1.0519
# Epoch 8/100
# 14048/14153 [============================>.] - ETA: 0s - loss: 1.1389
# Epoch 00008: val_loss improved from 1.05187 to 1.04999, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 204us/sample - loss: 1.1379 - val_loss: 1.0500
# Epoch 9/100
# 13984/14153 [============================>.] - ETA: 0s - loss: 1.1226
# Epoch 00009: val_loss improved from 1.04999 to 1.04586, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 199us/sample - loss: 1.1224 - val_loss: 1.0459
# Epoch 10/100
# 14144/14153 [============================>.] - ETA: 0s - loss: 1.0986
# Epoch 00010: val_loss improved from 1.04586 to 1.03583, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 199us/sample - loss: 1.0984 - val_loss: 1.0358
# Epoch 11/100
# 13952/14153 [============================>.] - ETA: 0s - loss: 1.0937
# Epoch 00011: val_loss improved from 1.03583 to 1.02792, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 186us/sample - loss: 1.0943 - val_loss: 1.0279
# Epoch 12/100
# 14144/14153 [============================>.] - ETA: 0s - loss: 1.0737
# Epoch 00012: val_loss did not improve from 1.02792
# 14153/14153 [==============================] - 3s 190us/sample - loss: 1.0742 - val_loss: 1.0337
# Epoch 13/100
# 14144/14153 [============================>.] - ETA: 0s - loss: 1.0707
# Epoch 00013: val_loss improved from 1.02792 to 1.01465, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 197us/sample - loss: 1.0705 - val_loss: 1.0147
# Epoch 14/100
# 14080/14153 [============================>.] - ETA: 0s - loss: 1.0652
# Epoch 00014: val_loss did not improve from 1.01465
# 14153/14153 [==============================] - 3s 196us/sample - loss: 1.0649 - val_loss: 1.0211
# Epoch 15/100
# 14048/14153 [============================>.] - ETA: 0s - loss: 1.0442
# Epoch 00015: val_loss did not improve from 1.01465
# 14153/14153 [==============================] - 3s 205us/sample - loss: 1.0442 - val_loss: 1.0601
# Epoch 16/100
# 14048/14153 [============================>.] - ETA: 0s - loss: 1.0482
# Epoch 00016: val_loss improved from 1.01465 to 1.01345, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 199us/sample - loss: 1.0459 - val_loss: 1.0134
# Epoch 17/100
# 14112/14153 [============================>.] - ETA: 0s - loss: 1.0204
# Epoch 00017: val_loss did not improve from 1.01345
# 14153/14153 [==============================] - 3s 189us/sample - loss: 1.0210 - val_loss: 1.0195
# Epoch 18/100
# 13888/14153 [============================>.] - ETA: 0s - loss: 1.0187
# Epoch 00018: val_loss did not improve from 1.01345
# 14153/14153 [==============================] - 3s 196us/sample - loss: 1.0172 - val_loss: 1.0342
# Epoch 19/100
# 13888/14153 [============================>.] - ETA: 0s - loss: 1.0121
# Epoch 00019: val_loss improved from 1.01345 to 1.00420, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 191us/sample - loss: 1.0121 - val_loss: 1.0042
# Epoch 20/100
# 13920/14153 [============================>.] - ETA: 0s - loss: 0.9971
# Epoch 00020: val_loss improved from 1.00420 to 1.00143, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 205us/sample - loss: 0.9972 - val_loss: 1.0014
# Epoch 21/100
# 13856/14153 [============================>.] - ETA: 0s - loss: 0.9802
# Epoch 00021: val_loss improved from 1.00143 to 0.99861, saving model to nn_model.w8
# 14153/14153 [==============================] - 3s 202us/sample - loss: 0.9802 - val_loss: 0.9986
# Epoch 22/100
# 13888/14153 [============================>.] - ETA: 0s - loss: 0.9754
# Epoch 00022: val_loss did not improve from 0.99861
# 14153/14153 [==============================] - 3s 201us/sample - loss: 0.9713 - val_loss: 1.0271
# Epoch 23/100
# 13888/14153 [============================>.] - ETA: 0s - loss: 0.9642
# Epoch 00023: val_loss did not improve from 0.99861
# 14153/14153 [==============================] - 3s 190us/sample - loss: 0.9611 - val_loss: 1.0155
# Epoch 24/100
# 13984/14153 [============================>.] - ETA: 0s - loss: 0.9680
# Epoch 00024: val_loss did not improve from 0.99861
# 14153/14153 [==============================] - 3s 190us/sample - loss: 0.9688 - val_loss: 1.0074
# Epoch 25/100
# 14080/14153 [============================>.] - ETA: 0s - loss: 0.9638
# Epoch 00025: val_loss did not improve from 0.99861
# 14153/14153 [==============================] - 3s 212us/sample - loss: 0.9643 - val_loss: 1.0036
# Epoch 26/100
# 14080/14153 [============================>.] - ETA: 0s - loss: 0.9619
# Epoch 00026: val_loss did not improve from 0.99861
# 14153/14153 [==============================] - 3s 211us/sample - loss: 0.9618 - val_loss: 1.0110
# Epoch 27/100
# 14016/14153 [============================>.] - ETA: 0s - loss: 0.9424
# Epoch 00027: val_loss did not improve from 0.99861
# 14153/14153 [==============================] - 3s 206us/sample - loss: 0.9404 - val_loss: 1.0077
# Epoch 28/100
# 13888/14153 [============================>.] - ETA: 0s - loss: 0.9302
# Epoch 00028: val_loss did not improve from 0.99861
# 14153/14153 [==============================] - 3s 197us/sample - loss: 0.9299 - val_loss: 0.9987
# Epoch 29/100
# 13920/14153 [============================>.] - ETA: 0s - loss: 0.9250
# Epoch 00029: val_loss did not improve from 0.99861
# 14153/14153 [==============================] - 3s 198us/sample - loss: 0.9278 - val_loss: 1.0051
# Epoch 30/100
# 13984/14153 [============================>.] - ETA: 0s - loss: 0.9141
# Epoch 00030: val_loss did not improve from 0.99861
# 14153/14153 [==============================] - 3s 189us/sample - loss: 0.9130 - val_loss: 1.0136
# Epoch 31/100
# 14048/14153 [============================>.] - ETA: 0s - loss: 0.9047
# Epoch 00031: val_loss did not improve from 0.99861
# 14153/14153 [==============================] - 3s 191us/sample - loss: 0.9045 - val_loss: 1.0408
# Epoch 32/100
# 14080/14153 [============================>.] - ETA: 0s - loss: 0.9077
# Epoch 00032: val_loss did not improve from 0.99861
# 14153/14153 [==============================] - 3s 202us/sample - loss: 0.9076 - val_loss: 1.0030
# Epoch 33/100
# 13984/14153 [============================>.] - ETA: 0s - loss: 0.8973
# Epoch 00033: val_loss did not improve from 0.99861
# 14153/14153 [==============================] - 3s 202us/sample - loss: 0.8967 - val_loss: 1.0171
# Epoch 34/100
# 14016/14153 [============================>.] - ETA: 0s - loss: 0.8910
# Epoch 00034: val_loss did not improve from 0.99861
# 14153/14153 [==============================] - 3s 196us/sample - loss: 0.8910 - val_loss: 1.0146
# Epoch 35/100
#  7904/14153 [===============>..............] - ETA: 1s - loss: 0.8873

# %%
weights = {'lbg': 0.60, 'cat': 0, 'xgb': 0.20, 'nn': 0.20}

final_pred = (lgb_model.y_pred * weights['lbg']) + (xgb_model.y_pred * weights['xgb']) + (nn_model.y_pred * weights['nn'])
#final_pred = cnn_model.y_pred
print(final_pred.shape)
# Out:
# (1000,)

# %%
#pd.DataFrame([(round(a, 2), round(b, 2), round(c, 2), round(d, 2)) for a, b, c, d in zip(lgb_model.y_pred, cat_model.y_pred, xgb_model.y_pred, nn_model.y_pred)], columns=['lgb', 'cat', 'xgb', 'nn']).head(50)

# %%
dist = Counter(reduce_train['accuracy_group'])
for k in dist:
    dist[k] /= len(reduce_train)
reduce_train['accuracy_group'].hist()

acum = 0
bound = {}
for i in range(3):
    acum += dist[i]
    bound[i] = np.percentile(final_pred, acum * 100)
print(bound)

def classify(x):
    if x <= bound[0]:
        return 0
    elif x <= bound[1]:
        return 1
    elif x <= bound[2]:
        return 2
    else:
        return 3
    
final_pred = np.array(list(map(classify, final_pred)))

sample_submission['accuracy_group'] = final_pred.astype(int)
sample_submission.to_csv('submission.csv', index=False)
sample_submission['accuracy_group'].value_counts(normalize=True)
# Out:
# {0: 1.2902581759191551, 1: 1.7107073084306939, 2: 1.9459208357672333}
# 3    0.500
# 0    0.239
# 1    0.136
# 2    0.125
# Name: accuracy_group, dtype: float64
